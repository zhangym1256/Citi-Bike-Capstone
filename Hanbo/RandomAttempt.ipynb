# %%
import numpy as np
import pandas as pd
import random
from datetime import datetime
from scipy.integrate import quad
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import time
import mplleaflet
pd.set_option('display.max_columns',60)

# %%
csv_files_2017 = [('2017' + "%.2d" + '-citibike-tripdata.csv') % i for i in range(1, 13)]
csv_files_2018 = [('2018' + "%.2d" + '-citibike-tripdata.csv') % i for i in range(1, 13)]
csv_files_2019 = [('2019' + "%.2d" + '-citibike-tripdata.csv') % i for i in range(1, 13)]
csv_files = csv_files_2017 + csv_files_2018 + csv_files_2019

# %%
def to_datetime(df):
    df1 = df.copy()
    df1['starttime'] = pd.to_datetime(df1['starttime'])
    df1['stoptime'] = pd.to_datetime(df1['stoptime'])
    df1['start_date'] = df1['starttime'].dt.date
    df1['start_time'] = df1['starttime'].dt.time
    df1['start_hour'] = df1['starttime'].dt.hour
    df1['start_min'] = df1['starttime'].dt.minute
    df1['start_year'] = df1['starttime'].dt.year
    df1['start_month'] = df1['starttime'].dt.month
    df1['start_dayofweek'] = df1['starttime'].dt.weekday   # Monday is 0, Sunday is 6
    #df1['start_dayofweek'] = df1['starttime'].dt.weekday_name  # The name of day in a week (e.g. Monday)
    df1['stop_date'] = df1['stoptime'].dt.date
    df1['stop_time'] = df1['stoptime'].dt.time
    df1['stop_hour'] = df1['stoptime'].dt.hour
    df1['stop_min'] = df1['stoptime'].dt.minute
    df1['stop_dayofweek'] = df1['stoptime'].dt.weekday
    return df1

# %%
def ignore_offpeak(df):
    df1 = df.copy()
    mask = df1['start_hour'].apply(lambda x: 5 <= x <= 22)
    return df1[mask]

# %%
def aggregated_data(df):
    # Define distance: if same start and end location, use average speed of 7.456mph to estimate distance.
    # If different locations, calculate Manhattan distance between two stations
    df['distance']=np.where(df['start_station_ID'] == df['end_station_ID'],df['trip_duration']*7.456/3600,
                            abs(df['start_station_longitude']-df['end_station_longitude'])*53+\
                            abs(df['start_station_latitude']-df['end_station_latitude'])*69)
    # Daily average of all stations for time-series analysis
    df_daily = df.groupby('start_date').agg({'trip_duration':['count','mean'],'distance':'mean'}).reset_index()
    df_daily.columns = ['start_date','trip_per_day','daily_avg_trip_duration','daily_avg_distance']
    df_daily_merged = df.merge(df_daily, how = 'left', on = 'start_date')
    # Hourly average for each station regardeless of days 
    df_hourly = df.groupby(['start_station_ID','start_hour']).\
    agg({'trip_duration':['count','mean'],'distance':'mean'}).reset_index()
    df_hourly.columns = ['start_station_ID','start_hour','trip_per_hour','hourly_avg_trip_duration','hourly_avg_distance']
    df_hourly_merged = df_daily_merged.merge(df_hourly, how = 'left', on = ['start_station_ID','start_hour'])
    # Calculate hourly trip counts, avg trip duration, and avg trip distance per station and merge to above df
    df_hourly_eachday = df.groupby(['start_station_ID','start_date','start_hour']).\
    agg({'trip_duration':['count','mean'],'distance':'mean'}).reset_index()
    df_hourly_eachday.columns = ['start_station_ID','start_date','start_hour','trip_per_hour_eachday','hourly_avg_trip_duration_eachday','hourly_avg_distance_eachday']
    df_hourly_eachday_merged = df_hourly_merged.merge(df_hourly_eachday, how = 'left', on = ['start_station_ID','start_date','start_hour'])
    return df_hourly_eachday_merged

# %%
def merge_bikecount(df):
    # groupby start station ID, date and hour to get hourly counts of trips per start station
    checkout = df.groupby(['start_station_ID','start_date','start_hour'])['trip_duration'].count().reset_index()
    checkout.columns = ['start_station_ID','start_date','start_hour','checkout_counts']
    # groupby end station ID, date, and hour to get hourly counts of trips per end station 
    checkin = df.groupby(['end_station_ID','stop_date','stop_hour'])[['trip_duration']].count().reset_index()
    checkin.columns=['end_station_ID','stop_date','stop_hour','checkin_counts']
    # Join dataframe to get station checkin and checkout counts 
    temp = pd.merge(checkout, checkin,  how='outer', left_on=['start_station_ID','start_date','start_hour'], 
                    right_on = ['end_station_ID','stop_date','stop_hour'])
    temp['start_station_ID'] = temp['start_station_ID'].fillna(temp['end_station_ID'])
    temp['start_date'] = temp['start_date'].fillna(temp['stop_date'])
    temp['start_hour'] = temp['start_hour'].fillna(temp['stop_hour'])
    temp['checkout_counts'] = temp['checkout_counts'].fillna(0)
    temp['checkin_counts'] = temp['checkin_counts'].fillna(0)
    temp = temp.drop(['end_station_ID','stop_date','stop_hour'],axis=1)
    temp.columns=['station_ID','date','hour','checkout_counts','checkin_counts']
    temp['bike_added'] = temp['checkin_counts'] - temp['checkout_counts']
    # merge orginal dataframe to get hourly checkin/checkout information for both start and stop stations 
    df_temp_merged = pd.merge(df, temp,  how='left', left_on=['start_station_ID','start_date','start_hour'], 
         right_on = ['station_ID','date','hour']).drop(['station_ID','date','hour'],axis = 1)
    df_temp_merged = pd.merge(df_temp_merged, temp,  how='left', left_on=['end_station_ID','stop_date','stop_hour'], 
         right_on = ['station_ID','date','hour']).drop(['station_ID','date','hour'],axis = 1) 
    df_temp_merged = df_temp_merged.rename(columns={'checkout_counts_x':'start_station_checkout_counts',
                                                    'checkin_counts_x':'start_station_checkin_counts',
                                                    'bike_added_x':'start_station_bike_added', 
                                                    'checkout_counts_y':'end_station_checkout_counts',
                                                    'checkin_counts_y':'end_station_checkin_counts',
                                                    'bike_added_y':'end_station_bike_added'}) 
    return df_temp_merged

# %%
df = pd.DataFrame()
start_time = time.time()
random.seed(0)
path = './CitiBikeOriginal/'
divide_by = 20

# %%
for i, csv in enumerate(csv_files):
    df_temp = pd.read_csv(path+csv)
    df_temp.columns = ['trip_duration','starttime','stoptime','start_station_ID','start_station_name',
                       'start_station_latitude','start_station_longitude','end_station_ID','end_station_name',
                       'end_station_latitude','end_station_longitude','bike_ID','user_type','birth_year','gender']
    df_temp = df_temp.loc[df_temp['trip_duration']<= 24*3600]  
    df_temp = df_temp.loc[(df_temp['start_station_latitude']>40) & (df_temp['start_station_latitude']<41)]
    df_temp = to_datetime(df_temp)
    df_temp = ignore_offpeak(df_temp)
    #df_temp = merge_bikecount(df_temp)
    #df_temp = aggregated_data(df_temp)
    
    rows = len(df_temp)
    size = int(rows/divide_by)
    selected_idx = random.sample(range(1,rows), size)
    skip_idx = list(set(df_temp.index)-set(selected_idx))
    test_idx = random.sample(skip_idx,int(len(skip_idx)/divide_by))
    df_train = df_temp.iloc[selected_idx,:]
    #df_test = df_temp.iloc[test_idx,:]
    df_temp = df_train[['start_station_ID','start_station_name','start_station_latitude','start_station_longitude',
                        'end_station_ID','end_station_name','end_station_latitude','end_station_longitude',
                       'trip_duration']]    
    df = pd.concat([df, df_temp], axis = 0)
    print('Finishing ' + csv)
    
print('This block uses %.2f'%(time.time() - start_time) + ' seconds.' )
# Out:
# Finishing 201701-citibike-tripdata.csv
# Finishing 201702-citibike-tripdata.csv
# Finishing 201703-citibike-tripdata.csv
# Finishing 201704-citibike-tripdata.csv
# Finishing 201705-citibike-tripdata.csv
# Finishing 201706-citibike-tripdata.csv
# Finishing 201707-citibike-tripdata.csv
# Finishing 201708-citibike-tripdata.csv
# Finishing 201709-citibike-tripdata.csv
# Finishing 201710-citibike-tripdata.csv
# Finishing 201711-citibike-tripdata.csv
# Finishing 201712-citibike-tripdata.csv
# Finishing 201801-citibike-tripdata.csv
# Finishing 201802-citibike-tripdata.csv
# Finishing 201803-citibike-tripdata.csv
# Finishing 201804-citibike-tripdata.csv
# Finishing 201805-citibike-tripdata.csv
# Finishing 201806-citibike-tripdata.csv
# Finishing 201807-citibike-tripdata.csv
# Finishing 201808-citibike-tripdata.csv
# Finishing 201809-citibike-tripdata.csv
# Finishing 201810-citibike-tripdata.csv
# Finishing 201811-citibike-tripdata.csv
# Finishing 201812-citibike-tripdata.csv
# Finishing 201901-citibike-tripdata.csv
# Finishing 201902-citibike-tripdata.csv
# Finishing 201903-citibike-tripdata.csv
# Finishing 201904-citibike-tripdata.csv
# Finishing 201905-citibike-tripdata.csv
# Finishing 201906-citibike-tripdata.csv
# Finishing 201907-citibike-tripdata.csv
# Finishing 201908-citibike-tripdata.csv
# Finishing 201909-citibike-tripdata.csv
# Finishing 201910-citibike-tripdata.csv
# Finishing 201911-citibike-tripdata.csv
# Finishing 201912-citibike-tripdata.csv
# This block uses 322.27 seconds.

# %%
print('This dataframe has %d observations and %d variables.' %(df.shape[0],df.shape[1]))
# Out:
# This dataframe has 2625378 observations and 9 variables.

# %%
# combine start/end station ID/name into tuples
df_temp = df.astype('object')
#df_temp['route'] = list(zip(df_temp.start_station_ID, df_temp.end_station_ID))
df_temp['route_name'] = list(zip(df_temp.start_station_name, df_temp.end_station_name))
# create dictionaries from route and routename
route_dict = df_temp.route.value_counts().to_dict()
routename_dict = df_temp.route_name.value_counts().to_dict()

# %%
print('The proportion of of unique routes among all trips is %.2f'%(len(df_temp.route_name.unique())/df.shape[0]))
print('Total Possible Combinations is %d'%(1011*1010/2))
print('Total number of unique routes is %d'%len(df_temp.route_name.unique()))
# Out:
# The proportion of of unique routes among all trips is 0.10
# Total Possible Combinations is 510555
# Total number of unique routes is 252168

# %%
routename_dict
# Out:
# {('Central Park S & 6 Ave', 'Central Park S & 6 Ave'): 1120,
#  ('Central Park S & 6 Ave', '5 Ave & E 88 St'): 955,
#  ('E 7 St & Avenue A', 'Cooper Square & Astor Pl'): 851,
#  ('Grand Army Plaza & Central Park S',
#   'Grand Army Plaza & Central Park S'): 836,
#  ('W 21 St & 6 Ave', '9 Ave & W 22 St'): 751,
#  ('Pershing Square North', 'W 33 St & 7 Ave'): 723,
#  ('12 Ave & W 40 St', 'West St & Chambers St'): 711,
#  ('Pershing Square North', 'E 24 St & Park Ave S'): 661,
#  ('West Drive & Prospect Park West', 'West Drive & Prospect Park West'): 653,
#  ('S 4 St & Wythe Ave', 'N 6 St & Bedford Ave'): 650,
#  ('N 6 St & Bedford Ave', 'S 4 St & Wythe Ave'): 649,
#  ('Richardson St & N Henry St', 'Graham Ave & Conselyea St'): 606,
#  ('Pier 40 - Hudson River Park', 'West St & Chambers St'): 604,
#  ('Wythe Ave & Metropolitan Ave', 'N 6 St & Bedford Ave'): 602,
#  ('Centre St & Chambers St', 'Centre St & Chambers St'): 598,
#  ('Soissons Landing', 'Soissons Landing'): 595,
#  ('Grand Army Plaza & Central Park S', '5 Ave & E 88 St'): 590,
#  ('E 102 St & 1 Ave', '2 Ave & E 96 St'): 589,
#  ('McGuinness Blvd & Eagle St', 'Vernon Blvd & 50 Ave'): 588,
#  ('West St & Chambers St', 'Pier 40 - Hudson River Park'): 577,
#  ('S 3 St & Bedford Ave', 'N 6 St & Bedford Ave'): 569,
#  ('Vernon Blvd & 50 Ave', 'McGuinness Blvd & Eagle St'): 566,
#  ('12 Ave & W 40 St', 'Pier 40 - Hudson River Park'): 560,
#  ('West St & Chambers St', '12 Ave & W 40 St'): 554,
#  ('W 22 St & 10 Ave', 'W 22 St & 8 Ave'): 552,
#  ('Yankee Ferry Terminal', 'Yankee Ferry Terminal'): 549,
#  ('DeKalb Ave & Vanderbilt Ave', 'DeKalb Ave & Hudson Ave'): 548,
#  ('N 6 St & Bedford Ave', 'Wythe Ave & Metropolitan Ave'): 538,
#  ('Pershing Square North', 'Broadway & W 32 St'): 537,
#  ('West Thames St', 'South End Ave & Liberty St'): 536,
#  ('Soissons Landing', 'Yankee Ferry Terminal'): 532,
#  ('Little West St & 1 Pl', 'South End Ave & Liberty St'): 513,
#  ('South End Ave & Liberty St', 'West Thames St'): 511,
#  ('Central Park S & 6 Ave', '5 Ave & E 73 St'): 508,
#  ('Yankee Ferry Terminal', 'Soissons Landing'): 507,
#  ('E 10 St & Avenue A', 'Lafayette St & E 8 St'): 506,
#  ('6 Ave & W 33 St', 'Pershing Square North'): 504,
#  ('E 24 St & Park Ave S', 'Pershing Square North'): 501,
#  ('Willoughby St & Fleet St', 'Adelphi St & Myrtle Ave'): 498,
#  ('Graham Ave & Conselyea St', 'Richardson St & N Henry St'): 494,
#  ('E 13 St & Avenue A', 'Broadway & E 14 St'): 490,
#  ('Pershing Square North', 'W 41 St & 8 Ave'): 489,
#  ('5 Ave & E 73 St', '5 Ave & E 73 St'): 486,
#  ('E 30 St & Park Ave S', 'Pershing Square North'): 482,
#  ('W 26 St & 8 Ave', '11 Ave & W 27 St'): 481,
#  ('South End Ave & Liberty St', 'Little West St & 1 Pl'): 481,
#  ('Central Park West & W 72 St', 'Central Park West & W 72 St'): 477,
#  ('South End Ave & Liberty St', 'Broadway & Battery Pl'): 472,
#  ('11 Ave & W 27 St', 'W 26 St & 8 Ave'): 470,
#  ('W 33 St & 7 Ave', 'Pershing Square North'): 456,
#  ('W 21 St & 6 Ave', 'W 15 St & 7 Ave'): 453,
#  ('Broadway & W 60 St', '11 Ave & W 59 St'): 452,
#  ('Central Park S & 6 Ave',
#   'Central Park North & Adam Clayton Powell Blvd'): 452,
#  ('W 20 St & 11 Ave', 'West St & Chambers St'): 451,
#  ('University Pl & E 8 St', 'University Pl & E 14 St'): 451,
#  ('W 21 St & 6 Ave', 'W 22 St & 10 Ave'): 447,
#  ('Henry St & Grand St', 'Canal St & Rutgers St'): 443,
#  ('Willoughby Ave & Hall St', 'DeKalb Ave & Hudson Ave'): 442,
#  ('Broadway & W 41 St', 'Pershing Square North'): 442,
#  ('Picnic Point', 'Soissons Landing'): 441,
#  ('South End Ave & Liberty St', 'Bus Slip & State St'): 438,
#  ('Cooper Square & Astor Pl', 'E 6 St & Avenue B'): 438,
#  ('West St & Chambers St', 'Little West St & 1 Pl'): 437,
#  ('12 Ave & W 40 St', '12 Ave & W 40 St'): 437,
#  ('W 22 St & 10 Ave', 'W 21 St & 6 Ave'): 436,
#  ('Soissons Landing', 'Picnic Point'): 435,
#  ('11 Ave & W 41 St', '8 Ave & W 33 St'): 435,
#  ('Broadway & W 60 St', 'Broadway & W 60 St'): 433,
#  ('West St & Chambers St', 'W 20 St & 11 Ave'): 430,
#  ('Pershing Square North', 'E 30 St & Park Ave S'): 427,
#  ('Broadway & E 22 St', 'E 17 St & Broadway'): 427,
#  ('W 20 St & 11 Ave', 'W 20 St & 8 Ave'): 426,
#  ('Amsterdam Ave & W 73 St', 'Amsterdam Ave & W 79 St'): 424,
#  ('5 Ave & E 88 St', 'Central Park North & Adam Clayton Powell Blvd'): 424,
#  ('W 21 St & 6 Ave', 'W 22 St & 8 Ave'): 423,
#  ('Washington St & Gansevoort St', 'West St & Chambers St'): 419,
#  ('W 26 St & 8 Ave', 'W 27 St & 10 Ave'): 418,
#  ('Central Park S & 6 Ave', 'Central Park West & W 72 St'): 417,
#  ('8 Ave & W 33 St', 'Pershing Square North'): 416,
#  ('Adelphi St & Myrtle Ave', 'Willoughby St & Fleet St'): 415,
#  ('Pier 40 - Hudson River Park', 'Little West St & 1 Pl'): 415,
#  ('North Moore St & Greenwich St', 'Vesey Pl & River Terrace'): 415,
#  ('1 Ave & E 62 St', '1 Ave & E 68 St'): 415,
#  ('Central Park West & W 72 St', '5 Ave & E 73 St'): 414,
#  ('West St & Chambers St', 'Christopher St & Greenwich St'): 414,
#  ('W 26 St & 10 Ave', 'W 26 St & 8 Ave'): 413,
#  ('Christopher St & Greenwich St', 'West St & Chambers St'): 412,
#  ('Old Fulton St', 'Centre St & Chambers St'): 410,
#  ('Pershing Square North', 'Broadway & E 22 St'): 410,
#  ('Cadman Plaza E & Red Cross Pl', 'Centre St & Chambers St'): 409,
#  ('W 41 St & 8 Ave', 'Pershing Square North'): 407,
#  ('W 27 St & 10 Ave', 'W 26 St & 8 Ave'): 405,
#  ('E 47 St & Park Ave', 'W 41 St & 8 Ave'): 405,
#  ('E 32 St & Park Ave', '2 Ave & E 31 St'): 405,
#  ('Little West St & 1 Pl', 'Vesey Pl & River Terrace'): 405,
#  ('Pier 40 - Hudson River Park', 'South End Ave & Liberty St'): 404,
#  ('E 6 St & Avenue B', 'Cooper Square & Astor Pl'): 404,
#  ('Grand Army Plaza & Central Park S', 'Central Park S & 6 Ave'): 402,
#  ('Pier 40 - Hudson River Park', '12 Ave & W 40 St'): 400,
#  ('Central Park S & 6 Ave', '5 Ave & E 78 St'): 399,
#  ('Central Park West & W 72 St', 'Central Park S & 6 Ave'): 399,
#  ('1 Ave & E 16 St', 'E 15 St & 3 Ave'): 399,
#  ('West St & Chambers St', 'Washington St & Gansevoort St'): 398,
#  ('W 22 St & 8 Ave', 'W 22 St & 10 Ave'): 396,
#  ('Milton St & Franklin St', 'Kent Ave & N 7 St'): 396,
#  ('West St & Chambers St', 'West St & Chambers St'): 396,
#  ('Amsterdam Ave & W 73 St', 'Amsterdam Ave & W 82 St'): 395,
#  ('5 Ave & E 88 St', '5 Ave & E 88 St'): 391,
#  ('Broadway & E 22 St', 'Pershing Square North'): 390,
#  ('Pershing Square North', 'W 31 St & 7 Ave'): 390,
#  ('W 21 St & 6 Ave', 'W 20 St & 11 Ave'): 388,
#  ('Little West St & 1 Pl', 'West St & Chambers St'): 388,
#  ('Norfolk St & Broome St', 'Henry St & Grand St'): 387,
#  ('Vernon Blvd & 50 Ave', '46 Ave & 5 St'): 386,
#  ('Vesey Pl & River Terrace', 'North Moore St & Greenwich St'): 384,
#  ('46 Ave & 5 St', 'Vernon Blvd & 50 Ave'): 381,
#  ('Central Park West & W 68 St', 'Central Park West & W 68 St'): 379,
#  ('Broadway & E 14 St', 'Washington Pl & Broadway'): 378,
#  ('Columbus Ave & W 72 St', 'W 63 St & Broadway'): 373,
#  ('Canal St & Rutgers St', 'Henry St & Grand St'): 371,
#  ('W 42 St & 8 Ave', '11 Ave & W 41 St'): 371,
#  ('W 38 St & 8 Ave', 'Pershing Square North'): 370,
#  ('Lafayette St & E 8 St', 'E 17 St & Broadway'): 370,
#  ('Kent Ave & N 7 St', 'Milton St & Franklin St'): 368,
#  ('Central Park West & W 68 St', 'Central Park S & 6 Ave'): 368,
#  ('Clinton Ave & Myrtle Ave', 'Willoughby St & Fleet St'): 368,
#  ('W 22 St & 8 Ave', 'W 20 St & 11 Ave'): 368,
#  ('E 17 St & Broadway', '1 Ave & E 18 St'): 367,
#  ('Atlantic Ave & Furman St', 'Old Fulton St'): 366,
#  ('West Drive & Prospect Park West', 'Grand Army Plaza & Plaza St West'): 366,
#  ('11 Ave & W 27 St', '8 Ave & W 31 St'): 366,
#  ('Greenwich St & W Houston St', 'West St & Chambers St'): 365,
#  ('2 Ave & E 96 St', 'E 102 St & 1 Ave'): 365,
#  ('Pershing Square North', 'E 32 St & Park Ave'): 363,
#  ('Greenwich Ave & Charles St', 'Greenwich Ave & Charles St'): 361,
#  ('11 Ave & W 41 St', 'W 42 St & 8 Ave'): 361,
#  ('W 20 St & 11 Ave', 'W 21 St & 6 Ave'): 360,
#  ('Grand Army Plaza & Central Park S', 'Central Park West & W 72 St'): 360,
#  ('5 Ave & E 73 St', '5 Ave & E 88 St'): 360,
#  ('Pershing Square North', '8 Ave & W 33 St'): 359,
#  ('8 Ave & W 31 St', '11 Ave & W 27 St'): 359,
#  ('Henry St & Grand St', 'Norfolk St & Broome St'): 357,
#  ('Broadway & E 14 St', 'E 10 St & Avenue A'): 356,
#  ('W 31 St & 7 Ave', 'Pershing Square North'): 356,
#  ('South St & Gouverneur Ln', 'South St & Whitehall St'): 355,
#  ('Grand Army Plaza & Central Park S', '5 Ave & E 73 St'): 355,
#  ('W 20 St & 11 Ave', '8 Ave & W 31 St'): 354,
#  ('Willoughby St & Fleet St', 'Clinton Ave & Myrtle Ave'): 353,
#  ('E 20 St & FDR Drive', 'E 23 St & 1 Ave'): 352,
#  ('Central Park North & Adam Clayton Powell Blvd',
#   'Central Park West & W 72 St'): 351,
#  ('Berry St & N 8 St', 'Banker St & Meserole Ave'): 351,
#  ('Lafayette St & E 8 St', 'E 10 St & Avenue A'): 351,
#  ('Central Park West & W 85 St', 'Central Park S & 6 Ave'): 348,
#  ('9 Ave & W 22 St', 'W 21 St & 6 Ave'): 346,
#  ('E 32 St & Park Ave', 'Pershing Square North'): 345,
#  ('E 10 St & Avenue A', 'Broadway & E 14 St'): 344,
#  ('Broadway & Battery Pl', 'South End Ave & Liberty St'): 343,
#  ('Adelphi St & Myrtle Ave', 'DeKalb Ave & Hudson Ave'): 343,
#  ('Central Park West & W 72 St', '5 Ave & E 88 St'): 342,
#  ('S 4 St & Wythe Ave', 'Broadway & Roebling St'): 342,
#  ('Grand Army Plaza & Central Park S', 'Broadway & W 60 St'): 340,
#  ('Broadway & W 60 St', 'W 59 St & 10 Ave'): 338,
#  ('Cooper Square & Astor Pl', 'E 7 St & Avenue A'): 335,
#  ('Broadway & E 14 St', 'E 13 St & Avenue A'): 334,
#  ('1 Ave & E 16 St', 'E 17 St & Broadway'): 332,
#  ('W 20 St & 11 Ave', 'W 22 St & 8 Ave'): 332,
#  ('W 20 St & 11 Ave', 'W 20 St & 7 Ave'): 331,
#  ('Broadway & Berry St', 'N 6 St & Bedford Ave'): 331,
#  ('Broadway & E 22 St', 'E 23 St & 1 Ave'): 331,
#  ('Barclay St & Church St', '6 Ave & Canal St'): 330,
#  ('West St & Chambers St', 'Centre St & Chambers St'): 330,
#  ('3 St & Prospect Park West', 'Plaza St West & Flatbush Ave'): 330,
#  ('1 Ave & E 16 St', 'E 20 St & FDR Drive'): 329,
#  ('Grand Army Plaza & Plaza St West', 'West Drive & Prospect Park West'): 328,
#  ('Pershing Square North', '5 Ave & E 29 St'): 328,
#  ('E 24 St & Park Ave S', 'W 31 St & 7 Ave'): 327,
#  ('Broadway & W 36 St', 'Pershing Square North'): 326,
#  ('Christopher St & Greenwich St', 'Washington St & Gansevoort St'): 325,
#  ('Graham Ave & Conselyea St', 'Driggs Ave & N Henry St'): 325,
#  ('Greenwich St & W Houston St', 'Christopher St & Greenwich St'): 325,
#  ('Pershing Square North', 'E 17 St & Broadway'): 325,
#  ('Broadway & Berry St', 'Broadway & Roebling St'): 323,
#  ('South End Ave & Liberty St', 'West St & Chambers St'): 323,
#  ('Centre St & Chambers St', 'Cadman Plaza E & Tillary St'): 321,
#  ('Plaza St West & Flatbush Ave', '3 St & Prospect Park West'): 321,
#  ('Broadway & W 29 St', 'E 17 St & Broadway'): 320,
#  ('Vesey Pl & River Terrace', 'Little West St & 1 Pl'): 319,
#  ('1 Ave & E 18 St', 'E 17 St & Broadway'): 318,
#  ('Central Park West & W 72 St', 'Grand Army Plaza & Central Park S'): 317,
#  ('Carmine St & 6 Ave', 'Barrow St & Hudson St'): 317,
#  ('South End Ave & Liberty St', 'South End Ave & Liberty St'): 317,
#  ('Little West St & 1 Pl', 'Broadway & Battery Pl'): 317,
#  ('E 48 St & 5 Ave', 'W 49 St & 8 Ave'): 317,
#  ('Bedford Ave & Nassau Ave', 'N 8 St & Driggs Ave'): 317,
#  ('Broadway & W 29 St', 'Broadway & E 22 St'): 316,
#  ('5 Ave & E 88 St', 'Central Park West & W 85 St'): 315,
#  ('Lafayette St & E 8 St', 'Broadway & E 14 St'): 315,
#  ('Milton St & Franklin St', 'Berry St & N 8 St'): 314,
#  ('1 Ave & E 68 St', '1 Ave & E 78 St'): 314,
#  ('Grand Army Plaza & Central Park S', '5 Ave & E 78 St'): 314,
#  ('W 26 St & 8 Ave', 'W 26 St & 10 Ave'): 313,
#  ('Picnic Point', 'Yankee Ferry Terminal'): 313,
#  ('Broadway & Battery Pl', 'Little West St & 1 Pl'): 312,
#  ('Washington St & Gansevoort St', 'Christopher St & Greenwich St'): 312,
#  ('Bus Slip & State St', 'South End Ave & Liberty St'): 312,
#  ('Central Park West & W 68 St', 'Grand Army Plaza & Central Park S'): 311,
#  ('E 47 St & Park Ave', 'W 49 St & 8 Ave'): 310,
#  ('E 27 St & 1 Ave', 'W 31 St & 7 Ave'): 309,
#  ('Clinton St & Joralemon St', 'Henry St & Degraw St'): 308,
#  ('6 Ave & Canal St', 'Barclay St & Church St'): 307,
#  ('DeKalb Ave & S Portland Ave', 'DeKalb Ave & Hudson Ave'): 307,
#  ('Lafayette St & Jersey St', 'Lafayette St & E 8 St'): 306,
#  ('Yankee Ferry Terminal', 'Picnic Point'): 306,
#  ('Central Park North & Adam Clayton Powell Blvd',
#   'Central Park S & 6 Ave'): 306,
#  ('W 52 St & 6 Ave', 'W 33 St & 7 Ave'): 305,
#  ('W 63 St & Broadway', 'Broadway & W 60 St'): 305,
#  ('Old Fulton St', 'Atlantic Ave & Furman St'): 305,
#  ('Liberty St & Broadway', 'Broadway & Battery Pl'): 304,
#  ('Central Park North & Adam Clayton Powell Blvd',
#   'Central Park North & Adam Clayton Powell Blvd'): 304,
#  ('Carmine St & 6 Ave', 'W 21 St & 6 Ave'): 304,
#  ('5 Ave & E 73 St', 'Central Park North & Adam Clayton Powell Blvd'): 303,
#  ('W 37 St & 10 Ave', '8 Ave & W 33 St'): 303,
#  ('9 Ave & W 45 St', '8 Ave & W 33 St'): 303,
#  ('Old Fulton St', 'Old Fulton St'): 302,
#  ('W 34 St & 11 Ave', '11 Ave & W 27 St'): 302,
#  ('Lafayette St & E 8 St', 'E 7 St & Avenue A'): 302,
#  ('E 11 St & 1 Ave', 'Broadway & E 14 St'): 302,
#  ('Central Park West & W 76 St', 'Central Park S & 6 Ave'): 301,
#  ('8 Ave & W 33 St', 'W 37 St & 10 Ave'): 301,
#  ('1 Ave & E 16 St', 'E 23 St & 1 Ave'): 300,
#  ('W 41 St & 8 Ave', '11 Ave & W 41 St'): 299,
#  ('E 23 St & 1 Ave', 'E 20 St & FDR Drive'): 298,
#  ('Broadway & E 14 St', 'Lafayette St & E 8 St'): 297,
#  ('West St & Chambers St', 'South End Ave & Liberty St'): 296,
#  ('E 20 St & FDR Drive', 'Broadway & E 22 St'): 296,
#  ('8 Ave & W 33 St', 'W 49 St & 8 Ave'): 296,
#  ('5 Ave & E 73 St', 'Central Park West & W 72 St'): 295,
#  ('Grand Army Plaza & Plaza St West', 'Grand Army Plaza & Plaza St West'): 295,
#  ('Central Park North & Adam Clayton Powell Blvd',
#   'Central Park West & W 85 St'): 295,
#  ('University Pl & E 14 St', 'W 13 St & 7 Ave'): 294,
#  ('Broadway & W 49 St', 'E 48 St & 5 Ave'): 294,
#  ('Monroe St & Tompkins Ave', 'Macon St & Nostrand Ave'): 294,
#  ('Banker St & Meserole Ave', 'Berry St & N 8 St'): 292,
#  ('W 25 St & 6 Ave', 'Pershing Square North'): 292,
#  ('E 47 St & Park Ave', 'W 33 St & 7 Ave'): 292,
#  ('W 22 St & 10 Ave', 'Broadway & E 22 St'): 292,
#  ('W 70 St & Amsterdam Ave', 'Riverside Blvd & W 67 St'): 291,
#  ('8 Ave & W 52 St', 'W 53 St & 10 Ave'): 290,
#  ('Cleveland Pl & Spring St', 'Lafayette St & E 8 St'): 290,
#  ('Carmine St & 6 Ave', 'Mercer St & Bleecker St'): 290,
#  ('Broadway & W 60 St', 'Amsterdam Ave & W 73 St'): 289,
#  ('E 17 St & Broadway', 'Pershing Square North'): 289,
#  ('W 24 St & 7 Ave', 'W 22 St & 10 Ave'): 289,
#  ('West Thames St', 'Broadway & Battery Pl'): 288,
#  ('Clark St & Henry St', 'Hicks St & Montague St'): 288,
#  ('Berry St & N 8 St', 'Milton St & Franklin St'): 288,
#  ('W 34 St & 11 Ave', '12 Ave & W 40 St'): 287,
#  ('12 Ave & W 40 St', 'W 20 St & 11 Ave'): 287,
#  ('Cleveland Pl & Spring St', 'Great Jones St'): 287,
#  ('3 St & Prospect Park West', 'West Drive & Prospect Park West'): 286,
#  ('W 17 St & 8 Ave', 'W 20 St & 11 Ave'): 286,
#  ('W 21 St & 6 Ave', '6 Ave & W 33 St'): 286,
#  ('Canal St & Rutgers St', 'Division St & Bowery'): 284,
#  ('West St & Chambers St', 'Watts St & Greenwich St'): 283,
#  ('Columbus Ave & W 72 St', 'Central Park West & W 72 St'): 282,
#  ('W 20 St & 8 Ave', '8 Ave & W 31 St'): 281,
#  ('8 Ave & W 33 St', '11 Ave & W 41 St'): 280,
#  ('W 21 St & 6 Ave', '8 Ave & W 31 St'): 280,
#  ('E 7 St & Avenue A', 'Cooper Square & E 7 St'): 279,
#  ('W 49 St & 8 Ave', '9 Ave & W 45 St'): 279,
#  ('E 102 St & 1 Ave', 'E 103 St & Lexington Ave'): 279,
#  ('1 Ave & E 68 St', 'E 47 St & Park Ave'): 278,
#  ('W 47 St & 10 Ave', 'Broadway & W 49 St'): 277,
#  ('Kane St & Clinton St', 'Clinton St & Joralemon St'): 277,
#  ('Pershing Square North', 'W 27 St & 7 Ave'): 276,
#  ('E 2 St & Avenue B', 'Great Jones St'): 276,
#  ('N 6 St & Bedford Ave', 'Kent Ave & N 7 St'): 275,
#  ('Broadway & W 41 St', '11 Ave & W 41 St'): 274,
#  ('W 34 St & 11 Ave', '8 Ave & W 33 St'): 274,
#  ('E 17 St & Broadway', 'W 21 St & 6 Ave'): 274,
#  ('West St & Chambers St', 'Greenwich St & W Houston St'): 274,
#  ('W 22 St & 8 Ave', 'W 21 St & 6 Ave'): 273,
#  ('W 24 St & 7 Ave', 'W 15 St & 7 Ave'): 273,
#  ('West Thames St', 'West St & Chambers St'): 273,
#  ('E 17 St & Broadway', '1 Ave & E 16 St'): 272,
#  ('Great Jones St', 'E 17 St & Broadway'): 272,
#  ('Great Jones St', 'Lafayette St & E 8 St'): 272,
#  ('Centre St & Chambers St', 'Jay St & Tech Pl'): 272,
#  ('E 7 St & Avenue A', 'Broadway & E 14 St'): 271,
#  ('9 Ave & W 22 St', 'W 20 St & 11 Ave'): 271,
#  ('W 21 St & 6 Ave', 'W 20 St & 8 Ave'): 271,
#  ('E 32 St & Park Ave', 'E 33 St & 1 Ave'): 271,
#  ('Broadway & W 49 St', 'E 47 St & Park Ave'): 270,
#  ('South End Ave & Liberty St', 'Pier 40 - Hudson River Park'): 269,
#  ('1 Ave & E 62 St', '1 Ave & E 78 St'): 269,
#  ('5 Ave & E 78 St', '5 Ave & E 78 St'): 267,
#  ('Washington Park', 'DeKalb Ave & Hudson Ave'): 267,
#  ('Central Park West & W 68 St', '5 Ave & E 88 St'): 267,
#  ('Hicks St & Montague St', 'Clark St & Henry St'): 267,
#  ('45 Rd & 11 St', '46 Ave & 5 St'): 266,
#  ('Broadway & W 53 St', 'W 53 St & 10 Ave'): 266,
#  ('5 Ave & E 88 St', 'Central Park West & W 100 St'): 266,
#  ('E 31 St & 3 Ave', 'W 31 St & 7 Ave'): 266,
#  ('N 6 St & Bedford Ave', 'Bedford Ave & Nassau Ave'): 265,
#  ('Nassau Ave & Russell St', 'Leonard St & Nassau Ave'): 265,
#  ('E 20 St & Park Ave', 'Pershing Square North'): 265,
#  ('E 11 St & 2 Ave', 'Broadway & E 14 St'): 265,
#  ('Pershing Square North', 'E 20 St & Park Ave'): 265,
#  ('W 24 St & 7 Ave', 'W 27 St & 10 Ave'): 264,
#  ('Great Jones St', 'Broadway & E 14 St'): 263,
#  ('W 31 St & 7 Ave', 'Broadway & E 22 St'): 263,
#  ('Grand Army Plaza & Central Park S',
#   'Central Park North & Adam Clayton Powell Blvd'): 263,
#  ('South St & Whitehall St', 'South St & Gouverneur Ln'): 262,
#  ('W 26 St & 10 Ave', '8 Ave & W 31 St'): 262,
#  ('Sullivan St & Washington Sq', 'University Pl & E 14 St'): 261,
#  ('E 9 St & Avenue C', 'Broadway & E 14 St'): 261,
#  ('Pershing Square South', 'E 24 St & Park Ave S'): 260,
#  ('Broadway & W 25 St', 'E 17 St & Broadway'): 260,
#  ('Clark St & Henry St', 'Henry St & Atlantic Ave'): 260,
#  ('W 84 St & Columbus Ave', 'Columbus Ave & W 72 St'): 260,
#  ('11 Ave & W 41 St', 'W 34 St & 11 Ave'): 260,
#  ('E 15 St & 3 Ave', '1 Ave & E 18 St'): 259,
#  ('Broadway & W 60 St', '5 Ave & E 88 St'): 258,
#  ('E 32 St & Park Ave', '1 Ave & E 30 St'): 257,
#  ('Central Park S & 6 Ave', 'Broadway & W 60 St'): 257,
#  ('9 Ave & W 22 St', 'W 18 St & 6 Ave'): 257,
#  ('2 Ave & E 104 St', '2 Ave & E 96 St'): 257,
#  ('Central Park West & W 85 St', 'Grand Army Plaza & Central Park S'): 256,
#  ('5 Ave & E 88 St', 'Central Park West & W 72 St'): 256,
#  ('E 7 St & Avenue A', 'Lafayette St & E 8 St'): 256,
#  ('W 22 St & 8 Ave', '8 Ave & W 31 St'): 255,
#  ('Broadway & W 49 St', 'W 47 St & 10 Ave'): 255,
#  ('West Thames St', 'Vesey Pl & River Terrace'): 255,
#  ('W 20 St & 11 Ave', 'Christopher St & Greenwich St'): 255,
#  ('Clinton St & Grand St', 'Henry St & Grand St'): 255,
#  ('North Moore St & Greenwich St', 'Murray St & Greenwich St'): 254,
#  ('E 20 St & FDR Drive', '1 Ave & E 16 St'): 254,
#  ('Broadway & E 22 St', 'E 20 St & FDR Drive'): 254,
#  ('E 33 St & 2 Ave', 'W 33 St & 7 Ave'): 254,
#  ('West St & Chambers St', 'W 16 St & The High Line'): 254,
#  ('E 23 St & 1 Ave', 'Broadway & E 22 St'): 253,
#  ('1 Ave & E 30 St', 'Pershing Square North'): 252,
#  ('1 Ave & E 18 St', 'E 20 St & FDR Drive'): 252,
#  ('W 18 St & 6 Ave', 'E 17 St & Broadway'): 252,
#  ('W 22 St & 8 Ave', 'Broadway & E 22 St'): 252,
#  ('Pershing Square North', 'Broadway & W 36 St'): 252,
#  ('46 Ave & 5 St', '45 Rd & 11 St'): 252,
#  ('Broadway & Roebling St', 'S 4 St & Wythe Ave'): 251,
#  ('W 15 St & 7 Ave', 'E 16 St & 5 Ave'): 251,
#  ('Broadway & E 22 St', 'Broadway & E 14 St'): 250,
#  ('Broadway & E 22 St', 'W 31 St & 7 Ave'): 250,
#  ('St Marks Pl & 1 Ave', 'Lafayette St & E 8 St'): 250,
#  ('Broadway & W 41 St', 'E 47 St & Park Ave'): 250,
#  ('E 17 St & Broadway', 'Broadway & E 22 St'): 250,
#  ('E 85 St & York Ave', 'E 85 St & 3 Ave'): 250,
#  ('Ditmars Blvd & 19 St', '31 St & 23 Ave'): 249,
#  ('Broadway & Roebling St', 'Broadway & Berry St'): 249,
#  ('South End Ave & Liberty St', 'Liberty St & Broadway'): 249,
#  ('Pershing Square North', '6 Ave & W 33 St'): 249,
#  ('Grand St & Elizabeth St', 'Columbia St & Rivington St'): 249,
#  ('1 Ave & E 18 St', 'E 15 St & 3 Ave'): 249,
#  ('W 31 St & 7 Ave', 'E 24 St & Park Ave S'): 248,
#  ('Lafayette St & Jersey St', 'E 17 St & Broadway'): 248,
#  ('LaGuardia Pl & W 3 St', 'University Pl & E 14 St'): 248,
#  ('Pershing Square North', 'W 38 St & 8 Ave'): 248,
#  ('E 17 St & Broadway', 'W 31 St & 7 Ave'): 248,
#  ('1 Ave & E 30 St', 'W 31 St & 7 Ave'): 248,
#  ('E 15 St & 3 Ave', 'E 20 St & FDR Drive'): 248,
#  ('Stanton St & Chrystie St', 'Forsyth St & Broome St'): 247,
#  ('Pershing Square North', 'Broadway & W 29 St'): 247,
#  ('W 34 St & 11 Ave', 'West St & Chambers St'): 247,
#  ('E 33 St & 5 Ave', 'Pershing Square North'): 247,
#  ('W 15 St & 7 Ave', 'W 15 St & 10 Ave'): 246,
#  ('12 Ave & W 40 St', 'W 16 St & The High Line'): 246,
#  ('W 41 St & 8 Ave', 'E 47 St & Park Ave'): 246,
#  ('Pershing Square North', 'E 33 St & 5 Ave'): 246,
#  ('Little West St & 1 Pl', 'Pier 40 - Hudson River Park'): 245,
#  ('5 Ave & E 73 St', 'Central Park S & 6 Ave'): 245,
#  ('Henry St & Degraw St', 'Clinton St & Joralemon St'): 245,
#  ('E 33 St & 5 Ave', 'W 33 St & 7 Ave'): 245,
#  ('E 17 St & Broadway', 'E 20 St & 2 Ave'): 245,
#  ('Grand St & Elizabeth St', 'Clinton St & Grand St'): 244,
#  ('E 9 St & Avenue C', 'Lafayette St & E 8 St'): 244,
#  ('E 32 St & Park Ave', 'W 31 St & 7 Ave'): 244,
#  ('Pershing Square North', 'W 25 St & 6 Ave'): 243,
#  ('5 Ave & E 88 St', 'Central Park S & 6 Ave'): 243,
#  ('Broadway & W 49 St', 'W 46 St & 11 Ave'): 243,
#  ('E 17 St & Broadway', 'W 18 St & 6 Ave'): 243,
#  ('8 Ave & W 33 St', 'W 41 St & 8 Ave'): 242,
#  ('Broadway & E 22 St', 'E 20 St & 2 Ave'): 242,
#  ('Madison St & Montgomery St', 'Canal St & Rutgers St'): 242,
#  ('South St & Gouverneur Ln', 'South End Ave & Liberty St'): 242,
#  ('Driggs Ave & Lorimer St', 'N 8 St & Driggs Ave'): 242,
#  ('Little West St & 1 Pl', 'Murray St & West St'): 242,
#  ('Christopher St & Greenwich St', 'W 20 St & 11 Ave'): 241,
#  ('Kent Ave & N 7 St', 'N 6 St & Bedford Ave'): 241,
#  ('South End Ave & Liberty St', 'Water - Whitehall Plaza'): 240,
#  ('Broadway & W 60 St', 'W 67 St & Broadway'): 240,
#  ('Cadman Plaza E & Red Cross Pl', 'Front St & Washington St'): 240,
#  ('W 20 St & 7 Ave', 'W 20 St & 11 Ave'): 240,
#  ('W 15 St & 7 Ave', 'W 21 St & 6 Ave'): 240,
#  ('Plaza St West & Flatbush Ave', 'West Drive & Prospect Park West'): 240,
#  ('Barclay St & Church St', 'North Moore St & Greenwich St'): 240,
#  ('Broadway & W 60 St', '5 Ave & E 73 St'): 240,
#  ('W 25 St & 6 Ave', 'W 26 St & 10 Ave'): 239,
#  ('Broadway & W 60 St', 'Central Park West & W 72 St'): 239,
#  ('Columbus Ave & W 72 St', 'Grand Army Plaza & Central Park S'): 239,
#  ('W 20 St & 8 Ave', 'W 21 St & 6 Ave'): 239,
#  ('W 22 St & 10 Ave', 'W 24 St & 7 Ave'): 238,
#  ('W 33 St & 7 Ave', 'E 32 St & Park Ave'): 238,
#  ('Cleveland Pl & Spring St', 'Cleveland Pl & Spring St'): 238,
#  ('Lispenard St & Broadway', 'North Moore St & Greenwich St'): 238,
#  ('Central Park West & W 85 St', 'Central Park West & W 85 St'): 238,
#  ('E 16 St & 5 Ave', 'W 15 St & 7 Ave'): 238,
#  ('W 20 St & 8 Ave', 'W 20 St & 11 Ave'): 237,
#  ('West St & Chambers St', '11 Ave & W 27 St'): 237,
#  ('8 Ave & W 33 St', 'W 34 St & 11 Ave'): 237,
#  ('E 20 St & 2 Ave', 'Broadway & E 22 St'): 236,
#  ('3 St & Prospect Park West', '3 St & Prospect Park West'): 236,
#  ('11 Ave & W 41 St', 'Broadway & W 41 St'): 235,
#  ('W 44 St & 5 Ave', 'W 33 St & 7 Ave'): 235,
#  ('1 Ave & E 16 St', '1 Ave & E 30 St'): 235,
#  ('Washington St & Gansevoort St', 'South End Ave & Liberty St'): 235,
#  ('St Marks Pl & 1 Ave', 'Broadway & E 14 St'): 235,
#  ('Central Park West & W 76 St', 'Grand Army Plaza & Central Park S'): 235,
#  ('W 31 St & 7 Ave', 'E 30 St & Park Ave S'): 235,
#  ('Murray St & West St', 'West Thames St'): 234,
#  ('Barrow St & Hudson St', 'West St & Chambers St'): 234,
#  ('5 Ave & E 88 St', 'Central Park W & W 96 St'): 234,
#  ('W 15 St & 10 Ave', 'West St & Chambers St'): 233,
#  ('Metropolitan Ave & Meeker Ave', 'Metropolitan Ave & Bedford Ave'): 233,
#  ('E 12 St & 3 Ave', 'E 13 St & Avenue A'): 233,
#  ('Douglass St & 4 Ave', 'Dean St & 4 Ave'): 233,
#  ('W 21 St & 6 Ave', 'W 26 St & 8 Ave'): 233,
#  ('W 52 St & 11 Ave', '8 Ave & W 33 St'): 233,
#  ('5 Ave & E 73 St', 'Grand Army Plaza & Central Park S'): 232,
#  ('North Moore St & Greenwich St', 'Barclay St & Church St'): 232,
#  ('Broadway & W 29 St', 'Pershing Square North'): 232,
#  ('W 16 St & The High Line', 'W 15 St & 7 Ave'): 232,
#  ('1 Ave & E 16 St', 'E 27 St & 1 Ave'): 232,
#  ('Christopher St & Greenwich St', 'Greenwich St & W Houston St'): 232,
#  ('Pier 40 - Hudson River Park', 'Vesey Pl & River Terrace'): 232,
#  ('8 Ave & W 33 St', '8 Ave & W 52 St'): 232,
#  ('8 Ave & W 31 St', 'W 20 St & 11 Ave'): 231,
#  ('Broadway & W 56 St', 'Broadway & W 49 St'): 231,
#  ('8 Ave & W 33 St', 'W 45 St & 8 Ave'): 231,
#  ('Broadway & W 41 St', '6 Ave & W 33 St'): 231,
#  ('Central Park S & 6 Ave', '5 Ave & E 93 St'): 231,
#  ('W 15 St & 7 Ave', 'W 20 St & 11 Ave'): 231,
#  ('Pershing Square North', 'E 39 St & 2 Ave'): 230,
#  ('E 48 St & 5 Ave', 'W 41 St & 8 Ave'): 230,
#  ('W 16 St & The High Line', 'E 16 St & 5 Ave'): 229,
#  ('West St & Chambers St', 'Barrow St & Hudson St'): 229,
#  ('Lafayette Ave & Classon Ave', 'Emerson Pl & Myrtle Ave'): 228,
#  ('5 Ave & E 78 St', 'Grand Army Plaza & Central Park S'): 228,
#  ('Broadway & Battery Pl', 'West Thames St'): 228,
#  ('W 31 St & 7 Ave', 'E 27 St & 1 Ave'): 228,
#  ('Water - Whitehall Plaza', 'South End Ave & Liberty St'): 228,
#  ('Driggs Ave & N Henry St', 'Graham Ave & Conselyea St'): 228,
#  ('Vesey Pl & River Terrace', 'Broadway & Battery Pl'): 227,
#  ('Broadway & E 14 St', 'E 7 St & Avenue A'): 227,
#  ('E 17 St & Broadway', 'W 15 St & 7 Ave'): 227,
#  ('Metropolitan Ave & Bedford Ave', 'S 4 St & Wythe Ave'): 227,
#  ('Greenwich St & W Houston St', '8 Ave & W 31 St'): 227,
#  ('Clark St & Henry St', 'Old Fulton St'): 227,
#  ('W 54 St & 9 Ave', '9 Ave & W 45 St'): 226,
#  ('N 6 St & Bedford Ave', 'Milton St & Franklin St'): 226,
#  ('Broadway & E 22 St', 'University Pl & E 14 St'): 226,
#  ('W 33 St & 7 Ave', 'W 44 St & 5 Ave'): 226,
#  ('E 20 St & Park Ave', 'E 20 St & 2 Ave'): 226,
#  ('Little West St & 1 Pl', 'Little West St & 1 Pl'): 226,
#  ('Columbus Ave & W 72 St', 'Broadway & W 60 St'): 225,
#  ('1 Ave & E 68 St', '1 Ave & E 62 St'): 225,
#  ('W 16 St & 8 Ave', 'E 16 St & 5 Ave'): 225,
#  ('W 15 St & 7 Ave', 'W 16 St & The High Line'): 225,
#  ('5 Ave & E 29 St', 'Pershing Square North'): 225,
#  ('W 49 St & 8 Ave', '8 Ave & W 33 St'): 225,
#  ('8 Ave & W 31 St', '8 Ave & W 52 St'): 224,
#  ('E 20 St & 2 Ave', 'E 15 St & 3 Ave'): 224,
#  ('Murray St & Greenwich St', 'Centre St & Chambers St'): 224,
#  ('South End Ave & Liberty St', '12 Ave & W 40 St'): 224,
#  ('Centre St & Chambers St', 'West St & Chambers St'): 224,
#  ('Broadway & W 60 St', 'Columbus Ave & W 72 St'): 224,
#  ('Central Park West & W 76 St', '5 Ave & E 73 St'): 223,
#  ('Hudson St & Reade St', 'North Moore St & Greenwich St'): 223,
#  ('West St & Chambers St', 'Carmine St & 6 Ave'): 223,
#  ('Pershing Square North', 'Lexington Ave & E 29 St'): 223,
#  ('E 47 St & Park Ave', '1 Ave & E 68 St'): 222,
#  ('46 Ave & 5 St', '44 Dr & 21 St'): 222,
#  ('W 38 St & 8 Ave', '8 Ave & W 52 St'): 222,
#  ('Clinton St & Union St', 'Clinton St & Joralemon St'): 222,
#  ('Central Park West & W 76 St', 'Central Park West & W 76 St'): 221,
#  ('Broadway & E 22 St', 'W 22 St & 10 Ave'): 221,
#  ('University Pl & E 14 St', 'University Pl & E 8 St'): 221,
#  ('E 20 St & 2 Ave', 'E 17 St & Broadway'): 221,
#  ('Clinton Ave & Myrtle Ave', 'DeKalb Ave & Hudson Ave'): 221,
#  ('Huron St & Franklin St', 'Vernon Blvd & 50 Ave'): 221,
#  ('E 47 St & Park Ave', 'W 52 St & 6 Ave'): 220,
#  ('Christopher St & Greenwich St', 'Vesey Pl & River Terrace'): 220,
#  ('12 Ave & W 40 St', 'Little West St & 1 Pl'): 220,
#  ('Central Park West & W 72 St', 'Broadway & W 60 St'): 220,
#  ('W 11 St & 6 Ave', 'W 21 St & 6 Ave'): 220,
#  ('E 103 St & Lexington Ave', 'E 102 St & 1 Ave'): 220,
#  ('Christopher St & Greenwich St', 'Watts St & Greenwich St'): 220,
#  ('Brooklyn Bridge Park - Pier 2', 'Brooklyn Bridge Park - Pier 2'): 220,
#  ('West St & Chambers St', 'W 34 St & 11 Ave'): 219,
#  ('E 68 St & 3 Ave', '1 Ave & E 68 St'): 219,
#  ('Halsey St & Tompkins Ave', 'Macon St & Nostrand Ave'): 219,
#  ('Central Park West & W 72 St', 'Central Park West & W 68 St'): 219,
#  ('3 Ave & E 62 St', '1 Ave & E 68 St'): 219,
#  ('University Pl & E 14 St', 'Greenwich Ave & 8 Ave'): 218,
#  ('Central Park S & 6 Ave', 'Central Park West & W 68 St'): 218,
#  ('Watts St & Greenwich St', 'West St & Chambers St'): 218,
#  ('W 27 St & 10 Ave', 'W 24 St & 7 Ave'): 218,
#  ('E 17 St & Broadway', 'W 17 St & 8 Ave'): 217,
#  ('Lafayette St & E 8 St', 'St Marks Pl & 1 Ave'): 217,
#  ('Pershing Square North', '2 Ave & E 31 St'): 217,
#  ('Central Park West & W 85 St', 'Central Park West & W 72 St'): 217,
#  ('W 20 St & 11 Ave', 'W 16 St & 8 Ave'): 216,
#  ('11 Ave & W 27 St', 'W 24 St & 7 Ave'): 216,
#  ('E 24 St & Park Ave S', 'Pershing Square South'): 216,
#  ('Berry St & N 8 St', 'Bedford Ave & Nassau Ave'): 216,
#  ('W 52 St & 6 Ave', 'W 41 St & 8 Ave'): 215,
#  ('Little West St & 1 Pl', '12 Ave & W 40 St'): 215,
#  ('W 17 St & 8 Ave', '8 Ave & W 31 St'): 215,
#  ('Liberty St & Broadway', 'Maiden Ln & Pearl St'): 215,
#  ('5 Ave & E 63 St', '5 Ave & E 88 St'): 215,
#  ('Broadway & W 56 St', 'E 48 St & 5 Ave'): 215,
#  ('E 47 St & Park Ave', 'FDR Drive & E 35 St'): 215,
#  ('W 20 St & 11 Ave', 'W 24 St & 7 Ave'): 214,
#  ('Broadway & W 60 St', 'Grand Army Plaza & Central Park S'): 214,
#  ('Vernon Blvd & 50 Ave', 'Huron St & Franklin St'): 214,
#  ('Leonard St & Nassau Ave', 'Nassau Ave & Russell St'): 214,
#  ('W 16 St & 8 Ave', 'W 20 St & 11 Ave'): 213,
#  ('Pier 40 - Hudson River Park', 'Pier 40 - Hudson River Park'): 213,
#  ('South End Ave & Liberty St', 'W 20 St & 11 Ave'): 213,
#  ('Great Jones St', 'Carmine St & 6 Ave'): 213,
#  ('Vesey Pl & River Terrace', 'Vesey Pl & River Terrace'): 212,
#  ('8 Ave & W 31 St', '9 Ave & W 22 St'): 212,
#  ('46 Ave & 5 St', '44 Dr & Jackson Ave'): 211,
#  ('Central Park North & Adam Clayton Powell Blvd', 'Broadway & W 60 St'): 211,
#  ('6 Ave & W 33 St', 'W 41 St & 8 Ave'): 211,
#  ('South End Ave & Liberty St', 'South St & Gouverneur Ln'): 211,
#  ('Carmine St & 6 Ave', 'W 18 St & 6 Ave'): 211,
#  ('1 Ave & E 16 St', 'Broadway & E 14 St'): 211,
#  ('Centre St & Chambers St', 'Cadman Plaza E & Red Cross Pl'): 211,
#  ('Broadway & E 14 St', 'E 9 St & Avenue C'): 211,
#  ('Division St & Bowery', 'Canal St & Rutgers St'): 211,
#  ('W 21 St & 6 Ave', 'W 31 St & 7 Ave'): 210,
#  ('Lexington Ave & E 24 St', 'W 31 St & 7 Ave'): 210,
#  ('Broadway & W 56 St', 'Broadway & W 41 St'): 210,
#  ('W 47 St & 10 Ave', '8 Ave & W 33 St'): 210,
#  ('Carmine St & 6 Ave', 'West St & Chambers St'): 210,
#  ('Vernon Blvd & 50 Ave', 'India St & Manhattan Ave'): 210,
#  ('Barrow St & Hudson St', 'Bank St & Hudson St'): 210,
#  ('Cleveland Pl & Spring St', 'E 17 St & Broadway'): 210,
#  ('E 20 St & Park Ave', 'E 20 St & FDR Drive'): 210,
#  ('W 82 St & Central Park West', 'Central Park West & W 85 St'): 209,
#  ('Carlton Ave & Park Ave', 'Willoughby St & Fleet St'): 209,
#  ('Broadway & W 56 St', 'E 47 St & Park Ave'): 209,
#  ('Amsterdam Ave & W 79 St', 'Amsterdam Ave & W 73 St'): 209,
#  ('E 48 St & 5 Ave', 'W 33 St & 7 Ave'): 209,
#  ('Columbus Ave & W 95 St', 'W 84 St & Columbus Ave'): 209,
#  ('Graham Ave & Herbert St', 'Graham Ave & Conselyea St'): 208,
#  ('Christopher St & Greenwich St', 'Carmine St & 6 Ave'): 208,
#  ('Grand Army Plaza & Central Park S', 'Central Park West & W 68 St'): 208,
#  ('W 56 St & 10 Ave', '8 Ave & W 33 St'): 208,
#  ('Centre St & Chambers St', 'Murray St & Greenwich St'): 208,
#  ('Graham Ave & Conselyea St', 'Graham Ave & Herbert St'): 208,
#  ('E 24 St & Park Ave S', 'W 38 St & 8 Ave'): 207,
#  ('Broadway & W 49 St', 'W 33 St & 7 Ave'): 207,
#  ('8 Ave & W 31 St', 'W 52 St & 6 Ave'): 207,
#  ('N 6 St & Bedford Ave', 'Broadway & Berry St'): 207,
#  ('Metropolitan Ave & Bedford Ave', 'Metropolitan Ave & Meeker Ave'): 207,
#  ('W 20 St & 11 Ave', 'W 15 St & 7 Ave'): 207,
#  ('W 18 St & 6 Ave', '6 Ave & W 33 St'): 207,
#  ('University Pl & E 8 St', 'E 12 St & 3 Ave'): 207,
#  ('6 Ave & W 33 St', 'Broadway & W 41 St'): 207,
#  ('Washington St & Gansevoort St', 'Washington St & Gansevoort St'): 207,
#  ('W 43 St & 10 Ave', '8 Ave & W 33 St'): 206,
#  ('8 Ave & W 31 St', 'Pershing Square North'): 206,
#  ('2 Ave & E 31 St', 'W 31 St & 7 Ave'): 206,
#  ('Pershing Square North', 'Broadway & W 41 St'): 205,
#  ('Cleveland Pl & Spring St', 'Grand St & Elizabeth St'): 205,
#  ('11 Ave & W 27 St', 'West St & Chambers St'): 205,
#  ('Brooklyn Bridge Park - Pier 2', 'Old Fulton St'): 205,
#  ('E 41 St & Madison Ave', 'W 33 St & 7 Ave'): 204,
#  ('5 Ave & E 78 St', 'Central Park S & 6 Ave'): 204,
#  ('W 22 St & 10 Ave', 'W 20 St & 7 Ave'): 204,
#  ('W 49 St & 8 Ave', 'W 47 St & 10 Ave'): 204,
#  ('E 85 St & 3 Ave', 'E 85 St & York Ave'): 204,
#  ('W 16 St & The High Line', 'West St & Chambers St'): 203,
#  ('E 17 St & Broadway', 'E 13 St & Avenue A'): 203,
#  ('W 41 St & 8 Ave', '8 Ave & W 52 St'): 203,
#  ('Liberty St & Broadway', 'Water - Whitehall Plaza'): 203,
#  ('Cleveland Pl & Spring St', 'MacDougal St & Prince St'): 203,
#  ('FDR Drive & E 35 St', 'E 47 St & Park Ave'): 203,
#  ('S 4 St & Wythe Ave', 'Berry St & N 8 St'): 203,
#  ('W 63 St & Broadway', '9 Ave & W 45 St'): 203,
#  ('W 20 St & 11 Ave', '12 Ave & W 40 St'): 203,
#  ('Amsterdam Ave & W 73 St', 'W 76 St & Columbus Ave'): 202,
#  ('Atlantic Ave & Furman St', 'Atlantic Ave & Furman St'): 202,
#  ('South End Ave & Liberty St', 'North Moore St & Greenwich St'): 202,
#  ('5 Ave & E 88 St', 'Grand Army Plaza & Central Park S'): 202,
#  ('Cadman Plaza E & Tillary St', 'Centre St & Chambers St'): 202,
#  ('W 22 St & 10 Ave', '8 Ave & W 31 St'): 201,
#  ('1 Ave & E 18 St', 'Broadway & E 22 St'): 201,
#  ('Barrow St & Hudson St', '8 Ave & W 31 St'): 201,
#  ('E 39 St & 2 Ave', '2 Ave & E 31 St'): 201,
#  ('Canal St & Rutgers St', 'Canal St & Rutgers St'): 201,
#  ('Canal St & Rutgers St', 'Forsyth St & Canal St'): 200,
#  ('S 4 St & Wythe Ave', 'Metropolitan Ave & Bedford Ave'): 200,
#  ('Broadway & W 29 St', 'Broadway & W 25 St'): 200,
#  ('W 24 St & 7 Ave', '9 Ave & W 22 St'): 200,
#  ('W 16 St & 8 Ave', '8 Ave & W 31 St'): 200,
#  ('Vesey Pl & River Terrace', 'Christopher St & Greenwich St'): 200,
#  ('Amsterdam Ave & W 73 St', 'W 84 St & Broadway'): 200,
#  ('Greenwich St & W Houston St', '12 Ave & W 40 St'): 200,
#  ('Great Jones St', 'E 12 St & 3 Ave'): 200,
#  ('Broadway & W 32 St', 'Pershing Square North'): 200,
#  ('Broadway & W 41 St', 'Broadway & E 22 St'): 199,
#  ('Milton St & Franklin St', 'N 6 St & Bedford Ave'): 199,
#  ('W 21 St & 6 Ave', 'W 38 St & 8 Ave'): 199,
#  ('Christopher St & Greenwich St', 'Greenwich Ave & 8 Ave'): 198,
#  ('11 Ave & W 59 St', '8 Ave & W 33 St'): 198,
#  ('Central Park West & W 68 St', '5 Ave & E 73 St'): 198,
#  ('9 Ave & W 45 St', 'W 44 St & 5 Ave'): 198,
#  ('W 63 St & Broadway', 'Amsterdam Ave & W 73 St'): 198,
#  ('E 25 St & 2 Ave', 'W 31 St & 7 Ave'): 198,
#  ('Pershing Square North', 'FDR Drive & E 35 St'): 198,
#  ('Columbus Ave & W 72 St', 'Columbus Ave & W 72 St'): 198,
#  ('1 Ave & E 110 St', '2 Ave & E 96 St'): 198,
#  ('W 27 St & 7 Ave', 'W 21 St & 6 Ave'): 197,
#  ('E 23 St & 1 Ave', '1 Ave & E 16 St'): 197,
#  ('W 27 St & 10 Ave', '8 Ave & W 31 St'): 197,
#  ('Vesey Pl & River Terrace', '12 Ave & W 40 St'): 197,
#  ('W 45 St & 8 Ave', '8 Ave & W 52 St'): 197,
#  ('E 20 St & FDR Drive', 'E 15 St & 3 Ave'): 197,
#  ('W 67 St & Broadway', 'Broadway & W 60 St'): 197,
#  ('Nassau Ave & Newell St', 'N 8 St & Driggs Ave'): 197,
#  ('W 26 St & 8 Ave', '8 Ave & W 31 St'): 196,
#  ('Cleveland Pl & Spring St', 'Broadway & E 14 St'): 196,
#  ('Vesey Pl & River Terrace', 'Washington St & Gansevoort St'): 196,
#  ('W 45 St & 8 Ave', '8 Ave & W 33 St'): 196,
#  ('E 30 St & Park Ave S', 'W 31 St & 7 Ave'): 196,
#  ('Pershing Square South', 'W 33 St & 7 Ave'): 196,
#  ('Broadway & Battery Pl', 'Vesey Pl & River Terrace'): 196,
#  ('Barrow St & Hudson St', 'Carmine St & 6 Ave'): 196,
#  ('E 12 St & 3 Ave', 'E 10 St & Avenue A'): 196,
#  ('Cooper Square & Astor Pl', 'E 10 St & Avenue A'): 195,
#  ('W 31 St & 7 Ave', '1 Ave & E 30 St'): 195,
#  ('Nassau Ave & Russell St', 'N 8 St & Driggs Ave'): 195,
#  ('12 Ave & W 40 St', 'W 34 St & 11 Ave'): 195,
#  ('E 17 St & Broadway', 'Lafayette St & E 8 St'): 195,
#  ('University Pl & E 14 St', 'W 4 St & 7 Ave S'): 195,
#  ('Kent Ave & S 11 St', 'Broadway & Roebling St'): 195,
#  ('Centre St & Chambers St', 'Murray St & West St'): 194,
#  ('W 27 St & 7 Ave', 'W 15 St & 7 Ave'): 194,
#  ('W 24 St & 7 Ave', 'Broadway & W 25 St'): 194,
#  ('Forsyth St & Broome St', 'Stanton St & Chrystie St'): 194,
#  ('9 Ave & W 22 St', 'Broadway & E 22 St'): 194,
#  ('Central Park S & 6 Ave', 'Central Park West & W 76 St'): 194,
#  ('Carroll St & Columbia St', 'Carroll St & Smith St'): 194,
#  ('W 21 St & 6 Ave', 'Pershing Square North'): 194,
#  ('W 4 St & 7 Ave S', 'Christopher St & Greenwich St'): 194,
#  ('W 16 St & The High Line', '8 Ave & W 31 St'): 194,
#  ('Central Park W & W 96 St', 'Central Park West & W 72 St'): 193,
#  ('Broadway & E 14 St', 'St Marks Pl & 1 Ave'): 193,
#  ('Columbus Ave & W 72 St', 'Central Park S & 6 Ave'): 193,
#  ('West St & Chambers St', 'West Thames St'): 193,
#  ('Broadway & W 49 St', 'E 48 St & 3 Ave'): 193,
#  ('West St & Chambers St', 'Bank St & Washington St'): 192,
#  ('W 31 St & 7 Ave', 'E 31 St & 3 Ave'): 192,
#  ('West Drive & Prospect Park West', 'Plaza St West & Flatbush Ave'): 192,
#  ('Broadway & W 25 St', 'Pershing Square North'): 192,
#  ('W 38 St & 8 Ave', 'Broadway & W 29 St'): 192,
#  ('Central Park W & W 96 St', 'Central Park S & 6 Ave'): 192,
#  ('Pershing Square South', 'W 41 St & 8 Ave'): 192,
#  ('Broadway & E 14 St', 'Great Jones St'): 192,
#  ('11 Ave & W 59 St', 'W 42 St & Dyer Ave'): 192,
#  ('1 Ave & E 18 St', '1 Ave & E 30 St'): 191,
#  ('Pershing Square North', 'E 33 St & 1 Ave'): 191,
#  ('University Pl & E 14 St', 'Sullivan St & Washington Sq'): 191,
#  ('Pier 40 - Hudson River Park', 'Bus Slip & State St'): 191,
#  ('7 Ave & Central Park South', '7 Ave & Central Park South'): 191,
#  ('E 11 St & 2 Ave', 'E 17 St & Broadway'): 191,
#  ('E 23 St & 1 Ave', 'Pershing Square North'): 190,
#  ('5 Ave & E 29 St', 'Broadway & E 22 St'): 190,
#  ('Lexington Ave & E 29 St', 'Broadway & W 29 St'): 190,
#  ('W 27 St & 7 Ave', '11 Ave & W 27 St'): 189,
#  ('Broadway & W 60 St', 'W 64 St & Thelonious Monk Circle'): 189,
#  ('E 20 St & Park Ave', '1 Ave & E 18 St'): 189,
#  ('Hanson Pl & Ashland Pl', 'Fulton St & Clermont Ave'): 189,
#  ('N 8 St & Driggs Ave', 'Bedford Ave & Nassau Ave'): 189,
#  ('Broadway & W 56 St', 'W 52 St & 11 Ave'): 189,
#  ('W 31 St & 7 Ave', 'E 17 St & Broadway'): 189,
#  ('E 25 St & 1 Ave', 'E 24 St & Park Ave S'): 189,
#  ('Stanton St & Chrystie St', 'Suffolk St & Stanton St'): 189,
#  ('5 Ave & E 73 St', 'Broadway & W 60 St'): 189,
#  ('31 St & 23 Ave', 'Ditmars Blvd & 19 St'): 189,
#  ('12 Ave & W 40 St', 'South End Ave & Liberty St'): 189,
#  ('Grand St & Elizabeth St', 'Canal St & Rutgers St'): 189,
#  ('E 15 St & 3 Ave', 'E 17 St & Broadway'): 188,
#  ('6 Ave & W 33 St', 'W 38 St & 8 Ave'): 188,
#  ('Broadway & E 22 St', 'W 15 St & 7 Ave'): 188,
#  ('W 25 St & 6 Ave', 'W 27 St & 10 Ave'): 188,
#  ('Broadway & W 25 St', 'W 24 St & 7 Ave'): 188,
#  ('Canal St & Rutgers St', 'Madison St & Montgomery St'): 188,
#  ('E 10 St & Avenue A', 'Cooper Square & Astor Pl'): 188,
#  ('W 44 St & 5 Ave', 'W 41 St & 8 Ave'): 188,
#  ('W 24 St & 7 Ave', 'W 26 St & 10 Ave'): 188,
#  ('Suffolk St & Stanton St', 'Lafayette St & Jersey St'): 188,
#  ('Murray St & West St', 'Little West St & 1 Pl'): 188,
#  ('E 39 St & 2 Ave', 'Pershing Square North'): 188,
#  ('Broadway & W 41 St', 'W 33 St & 7 Ave'): 187,
#  ('8 Ave & W 31 St', 'W 27 St & 10 Ave'): 187,
#  ('E 13 St & Avenue A', 'E 17 St & Broadway'): 187,
#  ('South St & Whitehall St', 'Peck Slip & Front St'): 187,
#  ('Lafayette St & E 8 St', 'Broadway & E 22 St'): 187,
#  ('E 6 St & Avenue B', 'Great Jones St'): 187,
#  ('E 19 St & 3 Ave', 'E 17 St & Broadway'): 187,
#  ('W 53 St & 10 Ave', '8 Ave & W 33 St'): 187,
#  ('E 24 St & Park Ave S', 'E 17 St & Broadway'): 187,
#  ('West St & Chambers St', 'Vesey Pl & River Terrace'): 186,
#  ('E 23 St & 1 Ave', 'E 24 St & Park Ave S'): 186,
#  ('E 15 St & 3 Ave', '1 Ave & E 16 St'): 186,
#  ('Vesey Pl & River Terrace', 'Bus Slip & State St'): 186,
#  ('W 31 St & 7 Ave', 'Broadway & W 25 St'): 186,
#  ('Pershing Square North', 'E 31 St & 3 Ave'): 186,
#  ('1 Ave & E 78 St', 'E 85 St & 3 Ave'): 186,
#  ('W 27 St & 7 Ave', 'Pershing Square North'): 186,
#  ('8 Ave & W 33 St', 'Pershing Square South'): 186,
#  ('W 21 St & 6 Ave', 'W 4 St & 7 Ave S'): 186,
#  ('E 31 St & 3 Ave', 'E 39 St & 3 Ave'): 185,
#  ('Metropolitan Ave & Bedford Ave', 'Hope St & Union Ave'): 185,
#  ('University Pl & E 14 St', 'E 13 St & Avenue A'): 185,
#  ('Henry St & Grand St', 'Clinton St & Grand St'): 185,
#  ('Central Park West & W 100 St', 'Central Park West & W 72 St'): 185,
#  ('Fulton St & Broadway', 'Broadway & Battery Pl'): 185,
#  ('W 46 St & 11 Ave', '8 Ave & W 33 St'): 185,
#  ('Murray St & West St', 'South End Ave & Liberty St'): 185,
#  ('Mott St & Prince St', 'MacDougal St & Prince St'): 185,
#  ('Broadway & E 14 St', 'W 13 St & 7 Ave'): 184,
#  ('E 25 St & 2 Ave', 'E 15 St & 3 Ave'): 184,
#  ('FDR Drive & E 35 St', 'Pershing Square North'): 184,
#  ('FDR Drive & E 35 St', '1 Ave & E 44 St'): 184,
#  ('Broadway & E 22 St', '1 Ave & E 18 St'): 184,
#  ('E 12 St & 3 Ave', 'E 7 St & Avenue A'): 184,
#  ('Broadway & E 22 St', '9 Ave & W 22 St'): 184,
#  ('W 56 St & 10 Ave', '9 Ave & W 45 St'): 184,
#  ('E 33 St & 1 Ave', 'W 33 St & 7 Ave'): 184,
#  ('Broadway & E 22 St', 'W 22 St & 8 Ave'): 184,
#  ('E 24 St & Park Ave S', 'E 25 St & 2 Ave'): 183,
#  ('Central Park W & W 96 St', 'Central Park W & W 96 St'): 183,
#  ('W 41 St & 8 Ave', 'W 49 St & 8 Ave'): 183,
#  ('W 26 St & 10 Ave', 'W 24 St & 7 Ave'): 183,
#  ('Macon St & Nostrand Ave', 'Halsey St & Tompkins Ave'): 183,
#  ('W 13 St & 7 Ave', 'University Pl & E 14 St'): 183,
#  ('West Thames St', 'Little West St & 1 Pl'): 183,
#  ('Carmine St & 6 Ave', 'Carmine St & 6 Ave'): 183,
#  ('Willoughby St & Fleet St', 'Washington Park'): 183,
#  ('Lafayette Ave & St James Pl', 'DeKalb Ave & Hudson Ave'): 183,
#  ('Barclay St & Church St', 'Lispenard St & Broadway'): 183,
#  ('1 Ave & E 78 St', 'E 77 St & 3 Ave'): 182,
#  ('W 21 St & 6 Ave', 'E 20 St & 2 Ave'): 182,
#  ('Christopher St & Greenwich St', 'Mercer St & Bleecker St'): 182,
#  ('Central Park West & W 68 St', 'Central Park West & W 85 St'): 182,
#  ('W 21 St & 6 Ave', 'W 27 St & 10 Ave'): 182,
#  ('E 17 St & Broadway', 'E 24 St & Park Ave S'): 182,
#  ('Centre St & Chambers St', 'Cleveland Pl & Spring St'): 182,
#  ('Forsyth St & Canal St', 'Forsyth St & Canal St'): 182,
#  ('MacDougal St & Prince St', 'Cleveland Pl & Spring St'): 182,
#  ('Christopher St & Greenwich St', 'Christopher St & Greenwich St'): 182,
#  ('E 12 St & 3 Ave', 'Washington Pl & Broadway'): 182,
#  ('Broadway & W 56 St', 'Broadway & W 51 St'): 182,
#  ('Central Park West & W 72 St', 'Central Park West & W 76 St'): 182,
#  ('E 13 St & Avenue A', 'E 7 St & Avenue A'): 182,
#  ('W 41 St & 8 Ave', 'Broadway & W 41 St'): 182,
#  ('E 47 St & Park Ave', 'Broadway & W 49 St'): 182,
#  ('W 49 St & 8 Ave', 'E 47 St & Park Ave'): 181,
#  ('Broadway & E 14 St', 'E 11 St & 2 Ave'): 181,
#  ('Broadway & E 22 St', 'W 21 St & 6 Ave'): 181,
#  ('E 25 St & 2 Ave', '1 Ave & E 16 St'): 181,
#  ('W 33 St & 7 Ave', '2 Ave & E 31 St'): 181,
#  ('1 Ave & E 30 St', 'W 33 St & 7 Ave'): 181,
#  ('1 Ave & E 18 St', 'E 20 St & Park Ave'): 181,
#  ('W 20 St & 11 Ave', '9 Ave & W 22 St'): 181,
#  ('Bank St & Washington St', 'West St & Chambers St'): 181,
#  ('1 Ave & E 16 St', 'E 25 St & 1 Ave'): 181,
#  ('MacDougal St & Washington Sq', 'University Pl & E 14 St'): 181,
#  ('E 47 St & Park Ave', 'E 58 St & 3 Ave'): 181,
#  ('Fulton St & Clermont Ave', 'Hanson Pl & Ashland Pl'): 181,
#  ('E 20 St & FDR Drive', 'E 17 St & Broadway'): 180,
#  ('E 7 St & Avenue A', 'Great Jones St'): 180,
#  ('Broadway & W 49 St', 'W 52 St & 11 Ave'): 180,
#  ('University Pl & E 14 St', 'W 21 St & 6 Ave'): 180,
#  ('Broadway & W 41 St', 'Broadway & W 25 St'): 180,
#  ('Broadway & E 14 St', '1 Ave & E 16 St'): 180,
#  ('5 Ave & E 78 St', 'Central Park North & Adam Clayton Powell Blvd'): 180,
#  ('Lafayette St & E 8 St', 'W 21 St & 6 Ave'): 180,
#  ('W 56 St & 10 Ave', 'Broadway & W 56 St'): 179,
#  ('5 Ave & E 88 St', '5 Ave & E 73 St'): 179,
#  ('West Thames St', 'West Thames St'): 179,
#  ('Carmine St & 6 Ave', 'Greenwich St & W Houston St'): 179,
#  ('8 Ave & W 31 St', 'W 49 St & 8 Ave'): 179,
#  ('Central Park West & W 85 St', '5 Ave & E 73 St'): 179,
#  ('6 Ave & 9 St', 'Carroll St & 6 Ave'): 179,
#  ('Central Park West & W 85 St', 'Broadway & W 60 St'): 179,
#  ('5 Ave & E 78 St', '5 Ave & E 88 St'): 179,
#  ('12 Ave & W 40 St', 'Christopher St & Greenwich St'): 179,
#  ('Great Jones St', 'E 2 St & Avenue B'): 178,
#  ('Pershing Square North', 'Broadway & W 25 St'): 178,
#  ('Broadway & E 14 St', 'University Pl & E 8 St'): 178,
#  ('Greenwich Ave & 8 Ave', 'W 22 St & 8 Ave'): 178,
#  ('Grand Army Plaza & Central Park S', 'Central Park West & W 76 St'): 178,
#  ('W 18 St & 6 Ave', 'Pershing Square North'): 178,
#  ('Broadway & W 60 St', 'Central Park West & W 68 St'): 178,
#  ('E 32 St & Park Ave', 'W 33 St & 7 Ave'): 178,
#  ('9 Ave & W 22 St', '8 Ave & W 31 St'): 177,
#  ('5 Ave & E 78 St', 'Broadway & W 60 St'): 177,
#  ('6 Ave & Canal St', 'Grand St & Elizabeth St'): 177,
#  ('W 45 St & 6 Ave', 'W 33 St & 7 Ave'): 177,
#  ('W 20 St & 11 Ave', 'South End Ave & Liberty St'): 177,
#  ('8 Ave & W 31 St', 'W 22 St & 10 Ave'): 177,
#  ('5 Ave & E 63 St', '5 Ave & E 63 St'): 177,
#  ('Howard St & Centre St', 'Great Jones St'): 177,
#  ('W 27 St & 7 Ave', 'W 27 St & 10 Ave'): 177,
#  ('1 Ave & E 68 St', 'Lexington Ave & E 63 St'): 176,
#  ('Amsterdam Ave & W 73 St', 'W 84 St & Columbus Ave'): 176,
#  ('W 34 St & 11 Ave', 'W 20 St & 11 Ave'): 176,
#  ('W 52 St & 6 Ave', '8 Ave & W 33 St'): 176,
#  ('Broadway & Battery Pl', 'West St & Chambers St'): 176,
#  ('W 52 St & 5 Ave', 'W 33 St & 7 Ave'): 176,
#  ('E 17 St & Broadway', 'E 23 St & 1 Ave'): 176,
#  ('Putnam Ave & Throop Ave', 'Macon St & Nostrand Ave'): 176,
#  ('W 89 St & Columbus Ave', 'Columbus Ave & W 72 St'): 176,
#  ('5 Ave & E 78 St', '5 Ave & E 73 St'): 176,
#  ('Congress St & Clinton St', 'Clinton St & Joralemon St'): 176,
#  ('Barclay St & Church St', 'Leonard St & Church St'): 176,
#  ('Watts St & Greenwich St', 'Christopher St & Greenwich St'): 176,
#  ('Broadway & E 14 St', 'St Marks Pl & 2 Ave'): 176,
#  ('Duffield St & Willoughby St', 'Hanson Pl & Ashland Pl'): 176,
#  ('E 32 St & Park Ave', 'E 33 St & 2 Ave'): 175,
#  ('Kent Ave & N 7 St', 'Kent Ave & N 7 St'): 175,
#  ('12 Ave & W 40 St', 'Greenwich St & W Houston St'): 175,
#  ('E 17 St & Broadway', 'E 19 St & 3 Ave'): 175,
#  ('W 16 St & The High Line', 'W 16 St & 8 Ave'): 175,
#  ('W 16 St & The High Line', 'W 22 St & 10 Ave'): 175,
#  ('E 13 St & Avenue A', 'University Pl & E 14 St'): 175,
#  ('West St & Chambers St', 'Broadway & Battery Pl'): 175,
#  ('Watts St & Greenwich St', 'Greenwich St & W Houston St'): 175,
#  ('South St & Gouverneur Ln', 'Little West St & 1 Pl'): 175,
#  ('Liberty St & Broadway', 'Front St & Maiden Ln'): 175,
#  ('Forsyth St & Canal St', 'Canal St & Rutgers St'): 175,
#  ('Broadway & Roebling St', 'Kent Ave & S 11 St'): 175,
#  ('E 47 St & Park Ave', 'Broadway & W 56 St'): 175,
#  ('Broadway & Berry St', 'Metropolitan Ave & Bedford Ave'): 175,
#  ('Vesey Pl & River Terrace', 'West Thames St'): 175,
#  ('W 27 St & 7 Ave', 'W 38 St & 8 Ave'): 175,
#  ('Greenwich St & W Houston St', 'Vesey Pl & River Terrace'): 175,
#  ('E 24 St & Park Ave S', 'E 25 St & 1 Ave'): 174,
#  ('W 52 St & 6 Ave', 'E 47 St & Park Ave'): 174,
#  ('8 Ave & W 31 St', '9 Ave & W 18 St'): 174,
#  ('W 49 St & 8 Ave', 'W 43 St & 10 Ave'): 174,
#  ('9 Ave & W 45 St', '9 Ave & W 28 St'): 174,
#  ('8 Ave & W 33 St', 'Broadway & W 49 St'): 174,
#  ('West Drive & Prospect Park West', '3 St & Prospect Park West'): 174,
#  ('Lexington Ave & E 29 St', 'Pershing Square North'): 173,
#  ('Central Park West & W 76 St', '5 Ave & E 88 St'): 173,
#  ('W 18 St & 6 Ave', 'W 31 St & 7 Ave'): 173,
#  ('E 5 St & Avenue C', 'Cooper Square & Astor Pl'): 173,
#  ('W 49 St & 8 Ave', 'E 48 St & 5 Ave'): 173,
#  ('W 49 St & 8 Ave', 'W 46 St & 11 Ave'): 173,
#  ('Broadway & Battery Pl', 'Broadway & Battery Pl'): 173,
#  ('Christopher St & Greenwich St', 'North Moore St & Greenwich St'): 172,
#  ('Barrow St & Hudson St', 'Greenwich Ave & 8 Ave'): 172,
#  ('8 Ave & W 31 St', 'W 45 St & 8 Ave'): 172,
#  ('Lafayette St & Jersey St', 'Broadway & E 14 St'): 172,
#  ('Broadway & W 58 St', 'Broadway & W 49 St'): 172,
#  ('8 Ave & W 52 St', '9 Ave & W 45 St'): 172,
#  ('Broadway & E 14 St', 'Cleveland Pl & Spring St'): 172,
#  ('Crescent St & Ditmars Blvd', '31 St & 23 Ave'): 172,
#  ('Broadway & W 41 St', 'Broadway & W 29 St'): 171,
#  ('Vernon Blvd & 50 Ave', 'Greenpoint Ave & Manhattan Ave'): 171,
#  ('2 Ave & E 31 St', 'E 25 St & 2 Ave'): 171,
#  ('Jay St & Tech Pl', 'Centre St & Chambers St'): 171,
#  ('12 Ave & W 40 St', '11 Ave & W 27 St'): 171,
#  ('8 Ave & W 31 St', 'W 26 St & 10 Ave'): 171,
#  ('Greenpoint Ave & Manhattan Ave', 'Vernon Blvd & 50 Ave'): 171,
#  ('Christopher St & Greenwich St', 'W 16 St & The High Line'): 171,
#  ('6 Ave & W 33 St', 'W 52 St & 6 Ave'): 171,
#  ('W 33 St & 7 Ave', 'W 52 St & 6 Ave'): 171,
#  ('Broadway & E 22 St', 'Broadway & E 22 St'): 171,
#  ('5 Ave & E 73 St', '5 Ave & E 78 St'): 171,
#  ('E 58 St & 3 Ave', 'E 47 St & Park Ave'): 171,
#  ('6 Ave & W 33 St', 'Pershing Square South'): 171,
#  ('Macon St & Nostrand Ave', 'Putnam Ave & Throop Ave'): 171,
#  ('44 Dr & 21 St', '46 Ave & 5 St'): 171,
#  ('Broadway & W 53 St', 'E 48 St & 5 Ave'): 170,
#  ('Broadway & E 14 St', 'E 11 St & 1 Ave'): 170,
#  ('E 33 St & 1 Ave', 'E 32 St & Park Ave'): 170,
#  ('Pershing Square North', '8 Ave & W 31 St'): 170,
#  ('5 Ave & E 88 St', 'Broadway & W 60 St'): 170,
#  ('Columbia St & Degraw St', 'Atlantic Ave & Furman St'): 170,
#  ('E 17 St & Broadway', 'E 17 St & Broadway'): 170,
#  ('DeKalb Ave & Hudson Ave', 'Clinton Ave & Myrtle Ave'): 170,
#  ('Carmine St & 6 Ave', 'Christopher St & Greenwich St'): 170,
#  ('Riverside Dr & W 72 St', 'Riverside Dr & W 72 St'): 170,
#  ('12 Ave & W 40 St', 'Riverside Dr & W 72 St'): 170,
#  ('W 84 St & Columbus Ave', 'Amsterdam Ave & W 73 St'): 170,
#  ('Columbia St & Rivington St', 'Grand St & Elizabeth St'): 170,
#  ('44 Dr & Jackson Ave', '46 Ave & 5 St'): 170,
#  ('2 Ave & E 31 St', 'E 20 St & 2 Ave'): 169,
#  ('Broadway & E 14 St', 'Mercer St & Bleecker St'): 169,
#  ('Lafayette St & E 8 St', 'E 9 St & Avenue C'): 169,
#  ('11 Ave & W 59 St', '12 Ave & W 40 St'): 169,
#  ('Union Ave & N 12 St', 'Metropolitan Ave & Bedford Ave'): 169,
#  ('Pershing Square North', 'E 25 St & 2 Ave'): 169,
#  ('Pershing Square South', 'Broadway & E 22 St'): 169,
#  ('8 Ave & W 33 St', 'W 43 St & 10 Ave'): 169,
#  ('E 33 St & 1 Ave', 'Pershing Square North'): 169,
#  ('W 27 St & 7 Ave', 'W 18 St & 6 Ave'): 169,
#  ('W 41 St & 8 Ave', 'W 52 St & 6 Ave'): 169,
#  ('W 38 St & 8 Ave', 'Broadway & E 22 St'): 168,
#  ('Greenwich St & W Houston St', 'South End Ave & Liberty St'): 168,
#  ('Henry St & Degraw St', 'Bergen St & Smith St'): 168,
#  ('W 33 St & 7 Ave', 'W 24 St & 7 Ave'): 168,
#  ('S 4 St & Wythe Ave', 'Kent Ave & N 7 St'): 168,
#  ('Central Park S & 6 Ave', 'Grand Army Plaza & Central Park S'): 168,
#  ('5 Ave & E 29 St', 'E 17 St & Broadway'): 168,
#  ('Riverside Blvd & W 67 St', 'W 70 St & Amsterdam Ave'): 168,
#  ('Grand St & Elizabeth St', 'Great Jones St'): 168,
#  ('W 41 St & 8 Ave', 'E 48 St & 5 Ave'): 168,
#  ('Willoughby St & Fleet St', 'Willoughby Ave & Hall St'): 168,
#  ('N 6 St & Bedford Ave', 'Kent Ave & S 11 St'): 167,
#  ('E 25 St & 2 Ave', 'E 11 St & 2 Ave'): 167,
#  ('Driggs Ave & N Henry St', 'N 8 St & Driggs Ave'): 167,
#  ('E 13 St & Avenue A', 'E 12 St & 3 Ave'): 167,
#  ('E 15 St & 3 Ave', 'E 24 St & Park Ave S'): 167,
#  ('E 47 St & Park Ave', 'Broadway & W 32 St'): 167,
#  ('1 Ave & E 16 St', 'Broadway & E 22 St'): 167,
#  ('South End Ave & Liberty St', 'Washington St & Gansevoort St'): 167,
#  ('Central Park West & W 68 St', 'Central Park West & W 72 St'): 166,
#  ('W 38 St & 8 Ave', '6 Ave & W 33 St'): 166,
#  ('Franklin Ave & St Marks Ave', 'Eastern Pkwy & Franklin Ave'): 166,
#  ('W 21 St & 6 Ave', 'W 20 St & 7 Ave'): 166,
#  ('W 21 St & 6 Ave', 'W 13 St & 7 Ave'): 166,
#  ('Vesey Pl & River Terrace', 'Pier 40 - Hudson River Park'): 166,
#  ('W 76 St & Columbus Ave', 'Central Park West & W 76 St'): 166,
#  ('Macon St & Nostrand Ave', 'Monroe St & Tompkins Ave'): 166,
#  ('E 7 St & Avenue A', 'E 17 St & Broadway'): 166,
#  ('W 27 St & 7 Ave', 'Broadway & E 22 St'): 166,
#  ('E 17 St & Broadway', 'E 10 St & Avenue A'): 166,
#  ('Broadway & E 14 St', 'LaGuardia Pl & W 3 St'): 166,
#  ('8 Ave & W 52 St', 'Broadway & W 60 St'): 166,
#  ('Central Park North & Adam Clayton Powell Blvd',
#   'Central Park West & W 76 St'): 166,
#  ('6 Ave & W 33 St', 'E 47 St & Park Ave'): 166,
#  ('E 24 St & Park Ave S', 'W 41 St & 8 Ave'): 166,
#  ('E 41 St & Madison Ave', 'Broadway & W 32 St'): 166,
#  ('E 10 St & Avenue A', 'E 10 St & Avenue A'): 166,
#  ('University Pl & E 14 St', 'MacDougal St & Washington Sq'): 165,
#  ('W 46 St & 11 Ave', 'Broadway & W 49 St'): 165,
#  ('Bayard St & Baxter St', 'Barclay St & Church St'): 165,
#  ('West St & Chambers St', '6 Ave & Canal St'): 165,
#  ('5 Ave & E 88 St', 'Central Park West & W 76 St'): 165,
#  ('Murray St & West St', 'Centre St & Chambers St'): 165,
#  ('E 10 St & Avenue A', 'Great Jones St'): 165,
#  ('W 21 St & 6 Ave', 'E 17 St & Broadway'): 165,
#  ('W 42 St & 8 Ave', 'Pershing Square North'): 165,
#  ('Central Park West & W 76 St', 'Central Park West & W 72 St'): 165,
#  ('W 13 St & 7 Ave', 'W 21 St & 6 Ave'): 165,
#  ('Carmine St & 6 Ave', 'Broadway & E 22 St'): 165,
#  ('E 17 St & Broadway', 'E 15 St & 3 Ave'): 165,
#  ('Stanton St & Chrystie St', 'Allen St & Hester St'): 165,
#  ('Central Park West & W 72 St', '5 Ave & E 78 St'): 165,
#  ('W 24 St & 7 Ave', 'W 13 St & 7 Ave'): 165,
#  ('W 34 St & 11 Ave', 'Pier 40 - Hudson River Park'): 164,
#  ('W 31 St & 7 Ave', 'W 24 St & 7 Ave'): 164,
#  ('West St & Chambers St', 'W 22 St & 10 Ave'): 164,
#  ('Milton St & Franklin St', 'Metropolitan Ave & Bedford Ave'): 164,
#  ('South St & Gouverneur Ln', 'Vesey Pl & River Terrace'): 164,
#  ('W 21 St & 6 Ave', 'Greenwich Ave & 8 Ave'): 164,
#  ('Liberty St & Broadway', 'Broad St & Bridge St'): 164,
#  ('West St & Chambers St', 'W 15 St & 10 Ave'): 164,
#  ('E 17 St & Broadway', '6 Ave & W 33 St'): 164,
#  ('E 39 St & 3 Ave', 'W 33 St & 7 Ave'): 164,
#  ('W 31 St & 7 Ave', '2 Ave & E 31 St'): 164,
#  ('E 20 St & FDR Drive', 'E 20 St & Park Ave'): 164,
#  ('North Moore St & Greenwich St', 'Hudson St & Reade St'): 164,
#  ('South St & Gouverneur Ln', 'South St & Gouverneur Ln'): 163,
#  ('FDR Drive & E 35 St', 'FDR Drive & E 35 St'): 163,
#  ('Milton St & Franklin St', 'Wythe Ave & Metropolitan Ave'): 163,
#  ('Cooper Square & Astor Pl', 'St Marks Pl & 1 Ave'): 163,
#  ('Pershing Square North', 'W 42 St & 8 Ave'): 163,
#  ('Mercer St & Spring St', 'Christopher St & Greenwich St'): 163,
#  ('Pershing Square North', 'W 21 St & 6 Ave'): 163,
#  ('6 Ave & W 33 St', 'E 32 St & Park Ave'): 163,
#  ('Plaza St West & Flatbush Ave', 'Garfield Pl & 8 Ave'): 163,
#  ('Broadway & W 49 St', 'W 41 St & 8 Ave'): 163,
#  ('W 31 St & 7 Ave', 'W 15 St & 7 Ave'): 163,
#  ...}

# %%
import json

# %%
with open('./station_information.json') as f:
  data = json.load(f)
#print(json.dumps(data, indent = 4, sort_keys=True))
station_dict = data['data']['stations']
dock_station_df = pd.DataFrame.from_dict(station_dict)[['station_id', 'name', 'capacity']]

# %%
with open('./stations.json') as f:
  data1 = json.load(f)
station_dict1 = data1['stationBeanList']
dock_station_df1 = pd.DataFrame.from_dict(station_dict1)[['id', 'stationName', 'totalDocks']]

# %%
dock_station_df.columns = ['start_station_ID', 'start_station_name', 'capacity']
dock_station_df1.columns = ['start_station_ID', 'start_station_name', 'capacity']

# %%
dock_station_df['capacity1'] = dock_station_df1['capacity']
dock_station_df['capacity'] = dock_station_df[["capacity", "capacity1"]].max(axis=1)
dock_station_df.drop('capacity1', axis = 1, inplace = True)
dock_station_df.to_csv('dock_station.csv')

# %%
docks = pd.read_csv('total_docks.csv', index_col = 0, parse_dates = True)

# %%
docks.start_date = pd.to_datetime(docks['start_date'])

# %%
docks_temp = docks.groupby('start_station_name').agg({'start_date': ['min', 'max']}).reset_index()

# %%
docks_temp.columns = ['start_station_name', 'min_date', 'max_date']

# %%
docks_temp
# Out:
#                start_station_name   min_date   max_date
# 0                1 Ave & E 110 St 2017-01-18 2019-04-19
# 1                 1 Ave & E 16 St 2017-01-17 2019-04-19
# 2                 1 Ave & E 18 St 2017-01-17 2019-04-19
# 3                 1 Ave & E 30 St 2017-01-17 2019-04-19
# 4                 1 Ave & E 44 St 2017-01-17 2019-04-19
# ..                            ...        ...        ...
# 762            Wyckoff St & 3 Ave 2017-01-17 2019-04-19
# 763  Wythe Ave & Metropolitan Ave 2017-01-17 2019-04-19
# 764         Yankee Ferry Terminal 2017-05-17 2018-10-18
# 765                       York St 2017-01-18 2019-04-19
# 766              York St & Jay St 2017-01-17 2019-04-17
#
# [767 rows x 3 columns]

# %%
pd.concat([pd.DataFrame({'Start': pd.date_range(row.min_date, row.max_date, freq='D')}, columns=['Date']) 
           for i, row in docks_temp.iterrows()], ignore_index=True)
# Out:
# Empty DataFrame
# Columns: [Date]
# Index: []

# %%
docks
# Out:
#        start_station_name start_date  tot_docks  start_year  start_month
# 207      1 Ave & E 110 St 2017-01-18         25        2017            1
# 208      1 Ave & E 110 St 2017-01-19         25        2017            1
# 209      1 Ave & E 110 St 2017-02-18         25        2017            2
# 210      1 Ave & E 110 St 2017-02-19         25        2017            2
# 211      1 Ave & E 110 St 2017-03-18         25        2017            3
# ...                   ...        ...        ...         ...          ...
# 472822   York St & Jay St 2019-02-17         27        2019            2
# 472823   York St & Jay St 2019-02-18         27        2019            2
# 472824   York St & Jay St 2019-03-17         27        2019            3
# 472825   York St & Jay St 2019-03-18          1        2019            3
# 472826   York St & Jay St 2019-04-17         27        2019            4
#
# [43849 rows x 5 columns]

# %%
docks
# Out:
#        start_station_name start_date  tot_docks  start_year  start_month
# 207      1 Ave & E 110 St 2017-01-18         25        2017            1
# 208      1 Ave & E 110 St 2017-01-19         25        2017            1
# 209      1 Ave & E 110 St 2017-02-18         25        2017            2
# 210      1 Ave & E 110 St 2017-02-19         25        2017            2
# 211      1 Ave & E 110 St 2017-03-18         25        2017            3
# ...                   ...        ...        ...         ...          ...
# 472822   York St & Jay St 2019-02-17         27        2019            2
# 472823   York St & Jay St 2019-02-18         27        2019            2
# 472824   York St & Jay St 2019-03-17         27        2019            3
# 472825   York St & Jay St 2019-03-18          1        2019            3
# 472826   York St & Jay St 2019-04-17         27        2019            4
#
# [43849 rows x 5 columns]

# %%
from itertools import product

# %%
station_list = list(docks['start_station_name'].unique())
date_list = list(pd.date_range(start='1/1/2017', end='12/31/2019').date)

# %%
station_date = pd.DataFrame(list(product(station_list, date_list)), columns=['start_station_name', 'start_date'])
station_date['start_date'] = pd.to_datetime(station_date['start_date'])

# %%
df = station_date.merge(docks, how = 'left', on = ['start_station_name', 'start_date'])

# %%
df.drop(['start_year', 'start_month'], axis = 1, inplace = True)

# %%
def fix(df, value):
    list_ = []
    length = len(df)
    for i in range(length):
        a = min(i, value)
        b = min(length - i, value)
        list_.append(max(df['tot_docks'][i - a: i + b]))
    return list_

# %%
df.tot_docks = df.tot_docks.apply(lambda x: round(x))
mask = np.isnan(df.tot_docks)
df['tot_docks'][mask] = np.interp(np.flatnonzero(mask), np.flatnonzero(~mask), df['tot_docks'][~mask])
# Out:
# /Users/hanboshao/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
station_list = list(df.start_station_name.unique())

# %%
dock_df = pd.DataFrame()

# %%
for station in station_list:
    df_temp = df[df.start_station_name == station]
    df_temp['tot_docks'] = fix(df_temp, 10)
    dock_df = pd.concat([dock_df, df_temp], axis = 0)
# Out:
# /Users/hanboshao/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-143-4fbda95c2f50> in <module>
#       1 for station in station_list:
#       2     df_temp = df[df.start_station_name == station]
# ----> 3     df_temp['tot_docks'] = fix(df_temp, 10)
#       4     dock_df = pd.concat([dock_df, df_temp], axis = 0)
#
# <ipython-input-139-3103bbe93734> in fix(df, value)
#       5         a = min(i, value)
#       6         b = min(length - i, value)
# ----> 7         list_.append(max(df['tot_docks'][i - a: i + b]))
#       8     return list_
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/base.py in __iter__(self)
#    1198         if is_datetimelike(self._values):
#    1199             return map(com.maybe_box_datetimelike, self._values)
# -> 1200         elif is_extension_array_dtype(self._values):
#    1201             return iter(self._values)
#    1202         else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/common.py in is_extension_array_dtype(arr_or_dtype)
#    1786     False
#    1787     """
# -> 1788     dtype = getattr(arr_or_dtype, "dtype", arr_or_dtype)
#    1789     return isinstance(dtype, ExtensionDtype) or registry.find(dtype) is not None
#    1790
#
# KeyboardInterrupt:

# %%
df.groupby('start_station_name').agg(lambda x: x.median())
# Out:
#                               tot_docks
# start_station_name
# 1 Ave & E 110 St                     25
# 1 Ave & E 16 St                      45
# 1 Ave & E 18 St                      39
# 1 Ave & E 30 St                      29
# 1 Ave & E 44 St                      41
# ...                                 ...
# Wyckoff St & 3 Ave                   22
# Wythe Ave & Metropolitan Ave         27
# Yankee Ferry Terminal                41
# York St                              22
# York St & Jay St                     27
#
# [767 rows x 1 columns]
